# %%
# import matplotlib.pyplot as plt
import mne
from mne_bids import BIDSPath, read_raw_bids
from bids import BIDSLayout
# from util.io.coherence import *
# from util.io.iter_BIDSPaths import *
# from util.io.preprocessing import *

BIDS_ROOT = '../../data/bids'
FS = 5000
RAW_TMIN = -0.2
RAW_TMAX = 0.5
TMIN = 0
TMAX = 0.25
N_CHANS = 62
CONDS = ['50', '100', '150', '200', '250']

layout = BIDSLayout(BIDS_ROOT, derivatives = True)
fpaths = layout.get(scope = 'preprocessing',
                    res = 'hi',
                    suffix='epo',
                    extension = 'fif.gz',
                    return_type = 'filename')
# Out:
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/bids/layout/validation.py:151: UserWarning: The PipelineDescription field was superseded by GeneratedBy in BIDS 1.4.0. You can use ``pybids upgrade`` to update your derivative dataset.
#   warnings.warn("The PipelineDescription field was superseded "

# %%
fpaths[35]
# Out:
# '/project2/hcn1/pitch_tracking/scripts/archive/../../data/bids/derivatives/preprocessing/sub-37/sub-37_task-pitch_run-1_res-hi_desc-clean_epo.fif.gz'

# %%
sub_34_epochs = mne.read_epochs(fpaths[32], preload = False)
sub_34_chans = sub_34_epochs.ch_names
print(f"number of channels for sub 34: {len(epochs.ch_names)}")
sub_35_epochs = mne.read_epochs(fpaths[33], preload = False)
sub_35_chans = sub_35_epochs.ch_names
print(f"number of channels for sub 35: {len(sub_35_epochs.ch_names)}")
# Out:
# Reading /project2/hcn1/pitch_tracking/scripts/archive/../../data/bids/derivatives/preprocessing/sub-34/sub-34_task-pitch_run-1_res-hi_desc-clean_epo.fif.gz ...
#     Found the data of interest:
#         t =    -200.00 ...     250.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 1921 matching events found
# No baseline correction applied
# 0 projection items activated
# number of channels for sub 34: 62
# Reading /project2/hcn1/pitch_tracking/scripts/archive/../../data/bids/derivatives/preprocessing/sub-35/sub-35_task-pitch_run-1_res-hi_desc-clean_epo.fif.gz ...
#     Found the data of interest:
#         t =    -200.00 ...     250.00 ms
#         0 CTF compensation matrices available
# Reading /project2/hcn1/pitch_tracking/scripts/archive/../../data/bids/derivatives/preprocessing/sub-35/sub-35_task-pitch_run-1_res-hi_desc-clean_epo.fif-1.gz ...
#     Found the data of interest:
#         t =    -200.00 ...     250.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 4676 matching events found
# No baseline correction applied
# 0 projection items activated
# number of channels for sub 35: 61

# %%
sub_37_epochs = mne.read_epochs(fpaths[35], preload = False)
sub_37_chans = sub_37_epochs.ch_names
print(f"number of channels for sub 35: {len(sub_37_epochs.ch_names)}")
# Out:
# Reading /project2/hcn1/pitch_tracking/scripts/archive/../../data/bids/derivatives/preprocessing/sub-37/sub-37_task-pitch_run-1_res-hi_desc-clean_epo.fif.gz ...
#     Found the data of interest:
#         t =    -200.00 ...     250.00 ms
#         0 CTF compensation matrices available
# Not setting metadata
# 3841 matching events found
# No baseline correction applied
# 0 projection items activated
# number of channels for sub 35: 61

# %%
set(sub_34_chans) ^ set(sub_37_chans)
# Out:
# {'T7'}

# %%
# import matplotlib.pyplot as plt
from mne_bids import BIDSPath, read_raw_bids
from bids import BIDSLayout
from util.io.coherence import *
from util.io.iter_BIDSPaths import *
from util.io.preprocessing import *

BIDS_ROOT = '../data/bids'
FIGS_ROOT = '../figs'
DERIV_ROOT = '../data/bids/derivatives'
FS = 5000
RAW_TMIN = -0.2
RAW_TMAX = 0.5
TMIN = 0
TMAX = 0.25
N_CHANS = 62
CONDS = ['50', '100', '150', '200', '250']

# # Subjects from which to generate stim signal
# STIM_SUB = 9
# STIM_RUN = 1

layout = BIDSLayout(BIDS_ROOT, derivatives = True)
fpaths = layout.get(scope = 'preprocessing',
                    res = 'hi',
                    suffix='epo',
                    extension = 'fif.gz',
                    return_type = 'filename')

for (FPATH, SUB, TASK, RUN) in iter_BIDSPaths(fpaths):
#     if SUB == '2':
#         continue
    
    epochs = mne.read_epochs(FPATH, preload = True)
    events = epochs.events
    n_epochs = len(events)
    
    # Create epochs from raw data to create simulated stim channels
    raw_epochs = get_raw_epochs(BIDS_ROOT, SUB, TASK, RUN)
    stim_epochs_array = create_stim_epochs_array(raw_epochs, n_epochs, SUB, CONDS)
    plot_stim_chans(FIGS_ROOT, SUB, RUN, RAW_TMIN, RAW_TMAX, stim_epochs_array)
    simulated_epochs = create_stim_epochs_object(stim_epochs_array, events, CONDS, FS, RAW_TMIN)

    # Crop data so both epochs have same windowing
    simulated_epochs = simulated_epochs.crop(tmin = TMIN, tmax = TMAX)
    epochs = epochs.crop(tmin = TMIN)

    # Add simulated channels to data
    combined_epochs = mne.epochs.add_channels_epochs([epochs, simulated_epochs])
    
    # Compute coherence
    indices = get_coh_indices(N_CHANS)
    fmin, fmax = get_fmin_and_fmax(CONDS)
    coh_df = pd.DataFrame()
    for cond in CONDS:
        coh = get_coh(cond, combined_epochs, indices, fmin, fmax, CONDS, FS)
        coh = clean_coh(coh, N_CHANS)
        cond_coh_df = create_coh_df(coh, cond, CONDS, N_CHANS, SUB)
        coh_df = pd.concat([coh_df, cond_coh_df])
    coh_df = coh_df.reset_index()

    # Write to pickle
    pickle_fp = f"{DERIV_ROOT}/coherence/subj-{SUB}_task-{TASK}_run-{RUN}_coh-by-condition.pkl"
    print(f"Writing coherence output to {pickle_fp}")
    coh_df.to_pickle(pickle_fp)
# Out:
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/bids/layout/validation.py:151: UserWarning: The PipelineDescription field was superseded by GeneratedBy in BIDS 1.4.0. You can use ``pybids upgrade`` to update your derivative dataset.
#   warnings.warn("The PipelineDescription field was superseded "
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/derivatives/preprocessing/sub-2/sub-2_task-pitch_run-1_res-hi_desc-clean_epo.fif.gz', '2', 'pitch', '1')
# Reading /project2/hcn1/pitch_tracking/scripts/../data/bids/derivatives/preprocessing/sub-2/sub-2_task-pitch_run-1_res-hi_desc-clean_epo.fif.gz ...
#     Found the data of interest:
#         t =    -200.00 ...     250.00 ms
#         0 CTF compensation matrices available
# Reading /project2/hcn1/pitch_tracking/scripts/../data/bids/derivatives/preprocessing/sub-2/sub-2_task-pitch_run-1_desc-clean_5khz_epo.fif-1.gz ...
#     Found the data of interest:
#         t =    -200.00 ...     250.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# 0 bad epochs dropped
# Not setting metadata
# 4553 matching events found
# No baseline correction applied
# 0 projection items activated
# /project2/hcn1/pitch_tracking/scripts/util/io/coherence.py:18: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /project2/hcn1/pitch_tracking/scripts/util/io/coherence.py:18: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 4564 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 968 events and 7001 original time points ...
# 0 bad epochs dropped
# Loading data for 921 events and 7001 original time points ...
# 0 bad epochs dropped
# Loading data for 975 events and 7001 original time points ...
# 0 bad epochs dropped
# Loading data for 969 events and 7001 original time points ...
# 0 bad epochs dropped
# Loading data for 731 events and 7001 original time points ...
# 0 bad epochs dropped
# Saving averaged aux channel plot to ../figs/subj-2_run-1_averaged_aux.png
# Not setting metadata
# 4553 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/io/meas_info.py:864: UserWarning: Avoid manually setting custom_ref_applied cannot be set directly. Please use method inst.set_eeg_reference() instead.
#   warnings.warn(f"Avoid manually setting {self._attributes[key]}")
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/io/meas_info.py:864: UserWarning: Avoid manually setting highpass cannot be set directly. Please use method inst.filter() instead.
#   warnings.warn(f"Avoid manually setting {self._attributes[key]}")
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/io/meas_info.py:864: UserWarning: Avoid manually setting lowpass cannot be set directly. Please use method inst.filter() instead.
#   warnings.warn(f"Avoid manually setting {self._attributes[key]}")
# 0 bad epochs dropped
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
#     computing connectivity for epoch 368
#     computing connectivity for epoch 369
#     computing connectivity for epoch 370
#     computing connectivity for epoch 371
#     computing connectivity for epoch 372
#     computing connectivity for epoch 373
#     computing connectivity for epoch 374
#     computing connectivity for epoch 375
#     computing connectivity for epoch 376
#     computing connectivity for epoch 377
#     computing connectivity for epoch 378
#     computing connectivity for epoch 379
#     computing connectivity for epoch 380
#     computing connectivity for epoch 381
#     computing connectivity for epoch 382
#     computing connectivity for epoch 383
#     computing connectivity for epoch 384
#     computing connectivity for epoch 385
#     computing connectivity for epoch 386
#     computing connectivity for epoch 387
#     computing connectivity for epoch 388
#     computing connectivity for epoch 389
#     computing connectivity for epoch 390
#     computing connectivity for epoch 391
#     computing connectivity for epoch 392
#     computing connectivity for epoch 393
#     computing connectivity for epoch 394
#     computing connectivity for epoch 395
#     computing connectivity for epoch 396
#     computing connectivity for epoch 397
#     computing connectivity for epoch 398
#     computing connectivity for epoch 399
#     computing connectivity for epoch 400
#     computing connectivity for epoch 401
#     computing connectivity for epoch 402
#     computing connectivity for epoch 403
#     computing connectivity for epoch 404
#     computing connectivity for epoch 405
#     computing connectivity for epoch 406
#     computing connectivity for epoch 407
#     computing connectivity for epoch 408
#     computing connectivity for epoch 409
#     computing connectivity for epoch 410
#     computing connectivity for epoch 411
#     computing connectivity for epoch 412
#     computing connectivity for epoch 413
#     computing connectivity for epoch 414
#     computing connectivity for epoch 415
#     computing connectivity for epoch 416
#     computing connectivity for epoch 417
#     computing connectivity for epoch 418
#     computing connectivity for epoch 419
#     computing connectivity for epoch 420
#     computing connectivity for epoch 421
#     computing connectivity for epoch 422
#     computing connectivity for epoch 423
#     computing connectivity for epoch 424
#     computing connectivity for epoch 425
#     computing connectivity for epoch 426
#     computing connectivity for epoch 427
#     computing connectivity for epoch 428
#     computing connectivity for epoch 429
#     computing connectivity for epoch 430
#     computing connectivity for epoch 431
#     computing connectivity for epoch 432
#     computing connectivity for epoch 433
#     computing connectivity for epoch 434
#     computing connectivity for epoch 435
#     computing connectivity for epoch 436
#     computing connectivity for epoch 437
#     computing connectivity for epoch 438
#     computing connectivity for epoch 439
#     computing connectivity for epoch 440
#     computing connectivity for epoch 441
#     computing connectivity for epoch 442
#     computing connectivity for epoch 443
#     computing connectivity for epoch 444
#     computing connectivity for epoch 445
#     computing connectivity for epoch 446
#     computing connectivity for epoch 447
#     computing connectivity for epoch 448
#     computing connectivity for epoch 449
#     computing connectivity for epoch 450
#     computing connectivity for epoch 451
#     computing connectivity for epoch 452
#     computing connectivity for epoch 453
#     computing connectivity for epoch 454
#     computing connectivity for epoch 455
#     computing connectivity for epoch 456
#     computing connectivity for epoch 457
#     computing connectivity for epoch 458
#     computing connectivity for epoch 459
#     computing connectivity for epoch 460
#     computing connectivity for epoch 461
#     computing connectivity for epoch 462
#     computing connectivity for epoch 463
#     computing connectivity for epoch 464
#     computing connectivity for epoch 465
#     computing connectivity for epoch 466
#     computing connectivity for epoch 467
#     computing connectivity for epoch 468
#     computing connectivity for epoch 469
#     computing connectivity for epoch 470
#     computing connectivity for epoch 471
#     computing connectivity for epoch 472
#     computing connectivity for epoch 473
#     computing connectivity for epoch 474
#     computing connectivity for epoch 475
#     computing connectivity for epoch 476
#     computing connectivity for epoch 477
#     computing connectivity for epoch 478
#     computing connectivity for epoch 479
#     computing connectivity for epoch 480
#     computing connectivity for epoch 481
#     computing connectivity for epoch 482
#     computing connectivity for epoch 483
#     computing connectivity for epoch 484
#     computing connectivity for epoch 485
#     computing connectivity for epoch 486
#     computing connectivity for epoch 487
#     computing connectivity for epoch 488
#     computing connectivity for epoch 489
#     computing connectivity for epoch 490
#     computing connectivity for epoch 491
#     computing connectivity for epoch 492
#     computing connectivity for epoch 493
#     computing connectivity for epoch 494
#     computing connectivity for epoch 495
#     computing connectivity for epoch 496
#     computing connectivity for epoch 497
#     computing connectivity for epoch 498
#     computing connectivity for epoch 499
#     computing connectivity for epoch 500
#     computing connectivity for epoch 501
#     computing connectivity for epoch 502
#     computing connectivity for epoch 503
#     computing connectivity for epoch 504
#     computing connectivity for epoch 505
#     computing connectivity for epoch 506
#     computing connectivity for epoch 507
#     computing connectivity for epoch 508
#     computing connectivity for epoch 509
#     computing connectivity for epoch 510
#     computing connectivity for epoch 511
#     computing connectivity for epoch 512
#     computing connectivity for epoch 513
#     computing connectivity for epoch 514
#     computing connectivity for epoch 515
#     computing connectivity for epoch 516
#     computing connectivity for epoch 517
#     computing connectivity for epoch 518
#     computing connectivity for epoch 519
#     computing connectivity for epoch 520
#     computing connectivity for epoch 521
#     computing connectivity for epoch 522
#     computing connectivity for epoch 523
#     computing connectivity for epoch 524
#     computing connectivity for epoch 525
#     computing connectivity for epoch 526
#     computing connectivity for epoch 527
#     computing connectivity for epoch 528
#     computing connectivity for epoch 529
#     computing connectivity for epoch 530
#     computing connectivity for epoch 531
#     computing connectivity for epoch 532
#     computing connectivity for epoch 533
#     computing connectivity for epoch 534
#     computing connectivity for epoch 535
#     computing connectivity for epoch 536
#     computing connectivity for epoch 537
#     computing connectivity for epoch 538
#     computing connectivity for epoch 539
#     computing connectivity for epoch 540
#     computing connectivity for epoch 541
#     computing connectivity for epoch 542
#     computing connectivity for epoch 543
#     computing connectivity for epoch 544
#     computing connectivity for epoch 545
#     computing connectivity for epoch 546
#     computing connectivity for epoch 547
#     computing connectivity for epoch 548
#     computing connectivity for epoch 549
#     computing connectivity for epoch 550
#     computing connectivity for epoch 551
#     computing connectivity for epoch 552
#     computing connectivity for epoch 553
#     computing connectivity for epoch 554
#     computing connectivity for epoch 555
#     computing connectivity for epoch 556
#     computing connectivity for epoch 557
#     computing connectivity for epoch 558
#     computing connectivity for epoch 559
#     computing connectivity for epoch 560
#     computing connectivity for epoch 561
#     computing connectivity for epoch 562
#     computing connectivity for epoch 563
#     computing connectivity for epoch 564
#     computing connectivity for epoch 565
#     computing connectivity for epoch 566
#     computing connectivity for epoch 567
#     computing connectivity for epoch 568
#     computing connectivity for epoch 569
#     computing connectivity for epoch 570
#     computing connectivity for epoch 571
#     computing connectivity for epoch 572
#     computing connectivity for epoch 573
#     computing connectivity for epoch 574
#     computing connectivity for epoch 575
#     computing connectivity for epoch 576
#     computing connectivity for epoch 577
#     computing connectivity for epoch 578
#     computing connectivity for epoch 579
#     computing connectivity for epoch 580
#     computing connectivity for epoch 581
#     computing connectivity for epoch 582
#     computing connectivity for epoch 583
#     computing connectivity for epoch 584
#     computing connectivity for epoch 585
#     computing connectivity for epoch 586
#     computing connectivity for epoch 587
#     computing connectivity for epoch 588
#     computing connectivity for epoch 589
#     computing connectivity for epoch 590
#     computing connectivity for epoch 591
#     computing connectivity for epoch 592
#     computing connectivity for epoch 593
#     computing connectivity for epoch 594
#     computing connectivity for epoch 595
#     computing connectivity for epoch 596
#     computing connectivity for epoch 597
#     computing connectivity for epoch 598
#     computing connectivity for epoch 599
#     computing connectivity for epoch 600
#     computing connectivity for epoch 601
#     computing connectivity for epoch 602
#     computing connectivity for epoch 603
#     computing connectivity for epoch 604
#     computing connectivity for epoch 605
#     computing connectivity for epoch 606
#     computing connectivity for epoch 607
#     computing connectivity for epoch 608
#     computing connectivity for epoch 609
#     computing connectivity for epoch 610
#     computing connectivity for epoch 611
#     computing connectivity for epoch 612
#     computing connectivity for epoch 613
#     computing connectivity for epoch 614
#     computing connectivity for epoch 615
#     computing connectivity for epoch 616
#     computing connectivity for epoch 617
#     computing connectivity for epoch 618
#     computing connectivity for epoch 619
#     computing connectivity for epoch 620
#     computing connectivity for epoch 621
#     computing connectivity for epoch 622
#     computing connectivity for epoch 623
#     computing connectivity for epoch 624
#     computing connectivity for epoch 625
#     computing connectivity for epoch 626
#     computing connectivity for epoch 627
#     computing connectivity for epoch 628
#     computing connectivity for epoch 629
#     computing connectivity for epoch 630
#     computing connectivity for epoch 631
#     computing connectivity for epoch 632
#     computing connectivity for epoch 633
#     computing connectivity for epoch 634
#     computing connectivity for epoch 635
#     computing connectivity for epoch 636
#     computing connectivity for epoch 637
#     computing connectivity for epoch 638
#     computing connectivity for epoch 639
#     computing connectivity for epoch 640
#     computing connectivity for epoch 641
#     computing connectivity for epoch 642
#     computing connectivity for epoch 643
#     computing connectivity for epoch 644
#     computing connectivity for epoch 645
#     computing connectivity for epoch 646
#     computing connectivity for epoch 647
#     computing connectivity for epoch 648
#     computing connectivity for epoch 649
#     computing connectivity for epoch 650
#     computing connectivity for epoch 651
#     computing connectivity for epoch 652
#     computing connectivity for epoch 653
#     computing connectivity for epoch 654
#     computing connectivity for epoch 655
#     computing connectivity for epoch 656
#     computing connectivity for epoch 657
#     computing connectivity for epoch 658
#     computing connectivity for epoch 659
#     computing connectivity for epoch 660
#     computing connectivity for epoch 661
#     computing connectivity for epoch 662
#     computing connectivity for epoch 663
#     computing connectivity for epoch 664
#     computing connectivity for epoch 665
#     computing connectivity for epoch 666
#     computing connectivity for epoch 667
#     computing connectivity for epoch 668
#     computing connectivity for epoch 669
#     computing connectivity for epoch 670
#     computing connectivity for epoch 671
#     computing connectivity for epoch 672
#     computing connectivity for epoch 673
#     computing connectivity for epoch 674
#     computing connectivity for epoch 675
#     computing connectivity for epoch 676
#     computing connectivity for epoch 677
#     computing connectivity for epoch 678
#     computing connectivity for epoch 679
#     computing connectivity for epoch 680
#     computing connectivity for epoch 681
#     computing connectivity for epoch 682
#     computing connectivity for epoch 683
#     computing connectivity for epoch 684
#     computing connectivity for epoch 685
#     computing connectivity for epoch 686
#     computing connectivity for epoch 687
#     computing connectivity for epoch 688
#     computing connectivity for epoch 689
#     computing connectivity for epoch 690
#     computing connectivity for epoch 691
#     computing connectivity for epoch 692
#     computing connectivity for epoch 693
#     computing connectivity for epoch 694
#     computing connectivity for epoch 695
#     computing connectivity for epoch 696
#     computing connectivity for epoch 697
#     computing connectivity for epoch 698
#     computing connectivity for epoch 699
#     computing connectivity for epoch 700
#     computing connectivity for epoch 701
#     computing connectivity for epoch 702
#     computing connectivity for epoch 703
#     computing connectivity for epoch 704
#     computing connectivity for epoch 705
#     computing connectivity for epoch 706
#     computing connectivity for epoch 707
#     computing connectivity for epoch 708
#     computing connectivity for epoch 709
#     computing connectivity for epoch 710
#     computing connectivity for epoch 711
#     computing connectivity for epoch 712
#     computing connectivity for epoch 713
#     computing connectivity for epoch 714
#     computing connectivity for epoch 715
#     computing connectivity for epoch 716
#     computing connectivity for epoch 717
#     computing connectivity for epoch 718
#     computing connectivity for epoch 719
#     computing connectivity for epoch 720
#     computing connectivity for epoch 721
#     computing connectivity for epoch 722
#     computing connectivity for epoch 723
#     computing connectivity for epoch 724
#     computing connectivity for epoch 725
#     computing connectivity for epoch 726
#     computing connectivity for epoch 727
#     computing connectivity for epoch 728
#     computing connectivity for epoch 729
#     computing connectivity for epoch 730
#     computing connectivity for epoch 731
#     computing connectivity for epoch 732
#     computing connectivity for epoch 733
#     computing connectivity for epoch 734
#     computing connectivity for epoch 735
#     computing connectivity for epoch 736
#     computing connectivity for epoch 737
#     computing connectivity for epoch 738
#     computing connectivity for epoch 739
#     computing connectivity for epoch 740
#     computing connectivity for epoch 741
#     computing connectivity for epoch 742
#     computing connectivity for epoch 743
#     computing connectivity for epoch 744
#     computing connectivity for epoch 745
#     computing connectivity for epoch 746
#     computing connectivity for epoch 747
#     computing connectivity for epoch 748
#     computing connectivity for epoch 749
#     computing connectivity for epoch 750
#     computing connectivity for epoch 751
#     computing connectivity for epoch 752
#     computing connectivity for epoch 753
#     computing connectivity for epoch 754
#     computing connectivity for epoch 755
#     computing connectivity for epoch 756
#     computing connectivity for epoch 757
#     computing connectivity for epoch 758
#     computing connectivity for epoch 759
#     computing connectivity for epoch 760
#     computing connectivity for epoch 761
#     computing connectivity for epoch 762
#     computing connectivity for epoch 763
#     computing connectivity for epoch 764
#     computing connectivity for epoch 765
#     computing connectivity for epoch 766
#     computing connectivity for epoch 767
#     computing connectivity for epoch 768
#     computing connectivity for epoch 769
#     computing connectivity for epoch 770
#     computing connectivity for epoch 771
#     computing connectivity for epoch 772
#     computing connectivity for epoch 773
#     computing connectivity for epoch 774
#     computing connectivity for epoch 775
#     computing connectivity for epoch 776
#     computing connectivity for epoch 777
#     computing connectivity for epoch 778
#     computing connectivity for epoch 779
#     computing connectivity for epoch 780
#     computing connectivity for epoch 781
#     computing connectivity for epoch 782
#     computing connectivity for epoch 783
#     computing connectivity for epoch 784
#     computing connectivity for epoch 785
#     computing connectivity for epoch 786
#     computing connectivity for epoch 787
#     computing connectivity for epoch 788
#     computing connectivity for epoch 789
#     computing connectivity for epoch 790
#     computing connectivity for epoch 791
#     computing connectivity for epoch 792
#     computing connectivity for epoch 793
#     computing connectivity for epoch 794
#     computing connectivity for epoch 795
#     computing connectivity for epoch 796
#     computing connectivity for epoch 797
#     computing connectivity for epoch 798
#     computing connectivity for epoch 799
#     computing connectivity for epoch 800
#     computing connectivity for epoch 801
#     computing connectivity for epoch 802
#     computing connectivity for epoch 803
#     computing connectivity for epoch 804
#     computing connectivity for epoch 805
#     computing connectivity for epoch 806
#     computing connectivity for epoch 807
#     computing connectivity for epoch 808
#     computing connectivity for epoch 809
#     computing connectivity for epoch 810
#     computing connectivity for epoch 811
#     computing connectivity for epoch 812
#     computing connectivity for epoch 813
#     computing connectivity for epoch 814
#     computing connectivity for epoch 815
#     computing connectivity for epoch 816
#     computing connectivity for epoch 817
#     computing connectivity for epoch 818
#     computing connectivity for epoch 819
#     computing connectivity for epoch 820
#     computing connectivity for epoch 821
#     computing connectivity for epoch 822
#     computing connectivity for epoch 823
#     computing connectivity for epoch 824
#     computing connectivity for epoch 825
#     computing connectivity for epoch 826
#     computing connectivity for epoch 827
#     computing connectivity for epoch 828
#     computing connectivity for epoch 829
#     computing connectivity for epoch 830
#     computing connectivity for epoch 831
#     computing connectivity for epoch 832
#     computing connectivity for epoch 833
#     computing connectivity for epoch 834
#     computing connectivity for epoch 835
#     computing connectivity for epoch 836
#     computing connectivity for epoch 837
#     computing connectivity for epoch 838
#     computing connectivity for epoch 839
#     computing connectivity for epoch 840
#     computing connectivity for epoch 841
#     computing connectivity for epoch 842
#     computing connectivity for epoch 843
#     computing connectivity for epoch 844
#     computing connectivity for epoch 845
#     computing connectivity for epoch 846
#     computing connectivity for epoch 847
#     computing connectivity for epoch 848
#     computing connectivity for epoch 849
#     computing connectivity for epoch 850
#     computing connectivity for epoch 851
#     computing connectivity for epoch 852
#     computing connectivity for epoch 853
#     computing connectivity for epoch 854
#     computing connectivity for epoch 855
#     computing connectivity for epoch 856
#     computing connectivity for epoch 857
#     computing connectivity for epoch 858
#     computing connectivity for epoch 859
#     computing connectivity for epoch 860
#     computing connectivity for epoch 861
#     computing connectivity for epoch 862
#     computing connectivity for epoch 863
#     computing connectivity for epoch 864
#     computing connectivity for epoch 865
#     computing connectivity for epoch 866
#     computing connectivity for epoch 867
#     computing connectivity for epoch 868
#     computing connectivity for epoch 869
#     computing connectivity for epoch 870
#     computing connectivity for epoch 871
#     computing connectivity for epoch 872
#     computing connectivity for epoch 873
#     computing connectivity for epoch 874
#     computing connectivity for epoch 875
#     computing connectivity for epoch 876
#     computing connectivity for epoch 877
#     computing connectivity for epoch 878
#     computing connectivity for epoch 879
#     computing connectivity for epoch 880
#     computing connectivity for epoch 881
#     computing connectivity for epoch 882
#     computing connectivity for epoch 883
#     computing connectivity for epoch 884
#     computing connectivity for epoch 885
#     computing connectivity for epoch 886
#     computing connectivity for epoch 887
#     computing connectivity for epoch 888
#     computing connectivity for epoch 889
#     computing connectivity for epoch 890
#     computing connectivity for epoch 891
#     computing connectivity for epoch 892
#     computing connectivity for epoch 893
#     computing connectivity for epoch 894
#     computing connectivity for epoch 895
#     computing connectivity for epoch 896
#     computing connectivity for epoch 897
#     computing connectivity for epoch 898
#     computing connectivity for epoch 899
#     computing connectivity for epoch 900
#     computing connectivity for epoch 901
#     computing connectivity for epoch 902
#     computing connectivity for epoch 903
#     computing connectivity for epoch 904
#     computing connectivity for epoch 905
#     computing connectivity for epoch 906
#     computing connectivity for epoch 907
#     computing connectivity for epoch 908
#     computing connectivity for epoch 909
#     computing connectivity for epoch 910
#     computing connectivity for epoch 911
#     computing connectivity for epoch 912
#     computing connectivity for epoch 913
#     computing connectivity for epoch 914
#     computing connectivity for epoch 915
#     computing connectivity for epoch 916
#     computing connectivity for epoch 917
#     computing connectivity for epoch 918
#     computing connectivity for epoch 919
#     computing connectivity for epoch 920
#     computing connectivity for epoch 921
#     computing connectivity for epoch 922
#     computing connectivity for epoch 923
#     computing connectivity for epoch 924
#     computing connectivity for epoch 925
#     computing connectivity for epoch 926
#     computing connectivity for epoch 927
#     computing connectivity for epoch 928
#     computing connectivity for epoch 929
#     computing connectivity for epoch 930
#     computing connectivity for epoch 931
#     computing connectivity for epoch 932
#     computing connectivity for epoch 933
#     computing connectivity for epoch 934
#     computing connectivity for epoch 935
#     computing connectivity for epoch 936
#     computing connectivity for epoch 937
#     computing connectivity for epoch 938
#     computing connectivity for epoch 939
#     computing connectivity for epoch 940
#     computing connectivity for epoch 941
#     computing connectivity for epoch 942
#     computing connectivity for epoch 943
#     computing connectivity for epoch 944
#     computing connectivity for epoch 945
#     computing connectivity for epoch 946
#     computing connectivity for epoch 947
#     computing connectivity for epoch 948
#     computing connectivity for epoch 949
#     computing connectivity for epoch 950
#     computing connectivity for epoch 951
#     computing connectivity for epoch 952
#     computing connectivity for epoch 953
#     computing connectivity for epoch 954
#     computing connectivity for epoch 955
#     computing connectivity for epoch 956
#     computing connectivity for epoch 957
#     computing connectivity for epoch 958
#     computing connectivity for epoch 959
#     computing connectivity for epoch 960
#     computing connectivity for epoch 961
#     computing connectivity for epoch 962
#     computing connectivity for epoch 963
#     computing connectivity for epoch 964
#     computing connectivity for epoch 965
#     computing connectivity for epoch 966
#     computing connectivity for epoch 967
# [Connectivity computation done]
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
# ...
#     computing connectivity for epoch 445
#     computing connectivity for epoch 446
#     computing connectivity for epoch 447
#     computing connectivity for epoch 448
#     computing connectivity for epoch 449
#     computing connectivity for epoch 450
#     computing connectivity for epoch 451
#     computing connectivity for epoch 452
#     computing connectivity for epoch 453
#     computing connectivity for epoch 454
#     computing connectivity for epoch 455
#     computing connectivity for epoch 456
#     computing connectivity for epoch 457
#     computing connectivity for epoch 458
#     computing connectivity for epoch 459
#     computing connectivity for epoch 460
#     computing connectivity for epoch 461
#     computing connectivity for epoch 462
#     computing connectivity for epoch 463
#     computing connectivity for epoch 464
#     computing connectivity for epoch 465
#     computing connectivity for epoch 466
#     computing connectivity for epoch 467
#     computing connectivity for epoch 468
#     computing connectivity for epoch 469
#     computing connectivity for epoch 470
#     computing connectivity for epoch 471
#     computing connectivity for epoch 472
#     computing connectivity for epoch 473
#     computing connectivity for epoch 474
#     computing connectivity for epoch 475
#     computing connectivity for epoch 476
#     computing connectivity for epoch 477
#     computing connectivity for epoch 478
#     computing connectivity for epoch 479
#     computing connectivity for epoch 480
#     computing connectivity for epoch 481
#     computing connectivity for epoch 482
#     computing connectivity for epoch 483
#     computing connectivity for epoch 484
#     computing connectivity for epoch 485
#     computing connectivity for epoch 486
#     computing connectivity for epoch 487
#     computing connectivity for epoch 488
#     computing connectivity for epoch 489
#     computing connectivity for epoch 490
#     computing connectivity for epoch 491
#     computing connectivity for epoch 492
#     computing connectivity for epoch 493
#     computing connectivity for epoch 494
#     computing connectivity for epoch 495
#     computing connectivity for epoch 496
#     computing connectivity for epoch 497
#     computing connectivity for epoch 498
#     computing connectivity for epoch 499
#     computing connectivity for epoch 500
#     computing connectivity for epoch 501
#     computing connectivity for epoch 502
#     computing connectivity for epoch 503
#     computing connectivity for epoch 504
#     computing connectivity for epoch 505
#     computing connectivity for epoch 506
#     computing connectivity for epoch 507
#     computing connectivity for epoch 508
#     computing connectivity for epoch 509
#     computing connectivity for epoch 510
#     computing connectivity for epoch 511
#     computing connectivity for epoch 512
#     computing connectivity for epoch 513
#     computing connectivity for epoch 514
#     computing connectivity for epoch 515
#     computing connectivity for epoch 516
#     computing connectivity for epoch 517
#     computing connectivity for epoch 518
#     computing connectivity for epoch 519
#     computing connectivity for epoch 520
#     computing connectivity for epoch 521
#     computing connectivity for epoch 522
#     computing connectivity for epoch 523
#     computing connectivity for epoch 524
#     computing connectivity for epoch 525
#     computing connectivity for epoch 526
#     computing connectivity for epoch 527
#     computing connectivity for epoch 528
#     computing connectivity for epoch 529
#     computing connectivity for epoch 530
#     computing connectivity for epoch 531
#     computing connectivity for epoch 532
#     computing connectivity for epoch 533
#     computing connectivity for epoch 534
#     computing connectivity for epoch 535
#     computing connectivity for epoch 536
#     computing connectivity for epoch 537
#     computing connectivity for epoch 538
#     computing connectivity for epoch 539
#     computing connectivity for epoch 540
#     computing connectivity for epoch 541
#     computing connectivity for epoch 542
#     computing connectivity for epoch 543
#     computing connectivity for epoch 544
#     computing connectivity for epoch 545
#     computing connectivity for epoch 546
#     computing connectivity for epoch 547
#     computing connectivity for epoch 548
#     computing connectivity for epoch 549
#     computing connectivity for epoch 550
#     computing connectivity for epoch 551
#     computing connectivity for epoch 552
#     computing connectivity for epoch 553
#     computing connectivity for epoch 554
#     computing connectivity for epoch 555
#     computing connectivity for epoch 556
#     computing connectivity for epoch 557
#     computing connectivity for epoch 558
#     computing connectivity for epoch 559
#     computing connectivity for epoch 560
#     computing connectivity for epoch 561
#     computing connectivity for epoch 562
#     computing connectivity for epoch 563
#     computing connectivity for epoch 564
#     computing connectivity for epoch 565
#     computing connectivity for epoch 566
#     computing connectivity for epoch 567
#     computing connectivity for epoch 568
#     computing connectivity for epoch 569
#     computing connectivity for epoch 570
#     computing connectivity for epoch 571
#     computing connectivity for epoch 572
#     computing connectivity for epoch 573
#     computing connectivity for epoch 574
#     computing connectivity for epoch 575
#     computing connectivity for epoch 576
#     computing connectivity for epoch 577
#     computing connectivity for epoch 578
#     computing connectivity for epoch 579
#     computing connectivity for epoch 580
#     computing connectivity for epoch 581
#     computing connectivity for epoch 582
#     computing connectivity for epoch 583
#     computing connectivity for epoch 584
#     computing connectivity for epoch 585
#     computing connectivity for epoch 586
#     computing connectivity for epoch 587
#     computing connectivity for epoch 588
#     computing connectivity for epoch 589
#     computing connectivity for epoch 590
#     computing connectivity for epoch 591
#     computing connectivity for epoch 592
#     computing connectivity for epoch 593
#     computing connectivity for epoch 594
#     computing connectivity for epoch 595
#     computing connectivity for epoch 596
#     computing connectivity for epoch 597
#     computing connectivity for epoch 598
#     computing connectivity for epoch 599
#     computing connectivity for epoch 600
#     computing connectivity for epoch 601
#     computing connectivity for epoch 602
#     computing connectivity for epoch 603
#     computing connectivity for epoch 604
#     computing connectivity for epoch 605
#     computing connectivity for epoch 606
#     computing connectivity for epoch 607
#     computing connectivity for epoch 608
#     computing connectivity for epoch 609
#     computing connectivity for epoch 610
#     computing connectivity for epoch 611
#     computing connectivity for epoch 612
#     computing connectivity for epoch 613
#     computing connectivity for epoch 614
#     computing connectivity for epoch 615
#     computing connectivity for epoch 616
#     computing connectivity for epoch 617
#     computing connectivity for epoch 618
#     computing connectivity for epoch 619
#     computing connectivity for epoch 620
#     computing connectivity for epoch 621
#     computing connectivity for epoch 622
#     computing connectivity for epoch 623
#     computing connectivity for epoch 624
#     computing connectivity for epoch 625
#     computing connectivity for epoch 626
#     computing connectivity for epoch 627
#     computing connectivity for epoch 628
#     computing connectivity for epoch 629
#     computing connectivity for epoch 630
#     computing connectivity for epoch 631
#     computing connectivity for epoch 632
#     computing connectivity for epoch 633
#     computing connectivity for epoch 634
#     computing connectivity for epoch 635
#     computing connectivity for epoch 636
#     computing connectivity for epoch 637
#     computing connectivity for epoch 638
#     computing connectivity for epoch 639
#     computing connectivity for epoch 640
#     computing connectivity for epoch 641
#     computing connectivity for epoch 642
#     computing connectivity for epoch 643
#     computing connectivity for epoch 644
#     computing connectivity for epoch 645
#     computing connectivity for epoch 646
#     computing connectivity for epoch 647
#     computing connectivity for epoch 648
#     computing connectivity for epoch 649
#     computing connectivity for epoch 650
#     computing connectivity for epoch 651
#     computing connectivity for epoch 652
#     computing connectivity for epoch 653
#     computing connectivity for epoch 654
#     computing connectivity for epoch 655
#     computing connectivity for epoch 656
#     computing connectivity for epoch 657
#     computing connectivity for epoch 658
#     computing connectivity for epoch 659
#     computing connectivity for epoch 660
#     computing connectivity for epoch 661
#     computing connectivity for epoch 662
#     computing connectivity for epoch 663
#     computing connectivity for epoch 664
#     computing connectivity for epoch 665
#     computing connectivity for epoch 666
#     computing connectivity for epoch 667
#     computing connectivity for epoch 668
#     computing connectivity for epoch 669
#     computing connectivity for epoch 670
#     computing connectivity for epoch 671
#     computing connectivity for epoch 672
#     computing connectivity for epoch 673
#     computing connectivity for epoch 674
#     computing connectivity for epoch 675
#     computing connectivity for epoch 676
#     computing connectivity for epoch 677
#     computing connectivity for epoch 678
#     computing connectivity for epoch 679
#     computing connectivity for epoch 680
#     computing connectivity for epoch 681
#     computing connectivity for epoch 682
#     computing connectivity for epoch 683
#     computing connectivity for epoch 684
#     computing connectivity for epoch 685
#     computing connectivity for epoch 686
#     computing connectivity for epoch 687
#     computing connectivity for epoch 688
#     computing connectivity for epoch 689
#     computing connectivity for epoch 690
#     computing connectivity for epoch 691
#     computing connectivity for epoch 692
#     computing connectivity for epoch 693
#     computing connectivity for epoch 694
#     computing connectivity for epoch 695
#     computing connectivity for epoch 696
#     computing connectivity for epoch 697
#     computing connectivity for epoch 698
#     computing connectivity for epoch 699
#     computing connectivity for epoch 700
#     computing connectivity for epoch 701
#     computing connectivity for epoch 702
#     computing connectivity for epoch 703
#     computing connectivity for epoch 704
#     computing connectivity for epoch 705
#     computing connectivity for epoch 706
#     computing connectivity for epoch 707
#     computing connectivity for epoch 708
#     computing connectivity for epoch 709
#     computing connectivity for epoch 710
#     computing connectivity for epoch 711
#     computing connectivity for epoch 712
#     computing connectivity for epoch 713
#     computing connectivity for epoch 714
#     computing connectivity for epoch 715
#     computing connectivity for epoch 716
#     computing connectivity for epoch 717
#     computing connectivity for epoch 718
#     computing connectivity for epoch 719
#     computing connectivity for epoch 720
#     computing connectivity for epoch 721
#     computing connectivity for epoch 722
#     computing connectivity for epoch 723
#     computing connectivity for epoch 724
#     computing connectivity for epoch 725
#     computing connectivity for epoch 726
#     computing connectivity for epoch 727
#     computing connectivity for epoch 728
#     computing connectivity for epoch 729
#     computing connectivity for epoch 730
# [Connectivity computation done]
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/derivatives/preprocessing/sub-3/sub-3_task-pitch_run-1_res-hi_desc-clean_epo.fif.gz', '3', 'pitch', '1')
# Reading /project2/hcn1/pitch_tracking/scripts/../data/bids/derivatives/preprocessing/sub-3/sub-3_task-pitch_run-1_res-hi_desc-clean_epo.fif.gz ...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [1], in <cell line: 30>()
#      24 fpaths = layout.get(scope = 'preprocessing',
#      25                     res = 'hi',
#      26                     suffix='epo',
#      27                     extension = 'fif.gz',
#      28                     return_type = 'filename')
#      30 for (FPATH, SUB, TASK, RUN) in iter_BIDSPaths(fpaths):
#      31 #     if SUB == '2':
#      32 #         continue
# ---> 34     epochs = mne.read_epochs(FPATH, preload = True)
#      35     events = epochs.events
#      36     n_epochs = len(events)
#
# File <decorator-gen-259>:12, in read_epochs(fname, proj, preload, verbose)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/epochs.py:3187, in read_epochs(fname, proj, preload, verbose)
#    3169 @verbose
#    3170 def read_epochs(fname, proj=True, preload=True, verbose=None):
#    3171     """Read epochs from a fif file.
#    3172
#    3173     Parameters
#    (...)
#    3185         The epochs.
#    3186     """
# -> 3187     return EpochsFIF(fname, proj, preload, verbose)
#
# File <decorator-gen-260>:12, in __init__(self, fname, proj, preload, verbose)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/epochs.py:3246, in EpochsFIF.__init__(self, fname, proj, preload, verbose)
#    3244 fname_rep = _get_fname_rep(fname)
#    3245 logger.info('Reading %s ...' % fname_rep)
# -> 3246 fid, tree, _ = fiff_open(fname, preload=preload)
#    3247 next_fname = _get_next_fname(fid, fname, tree)
#    3248 (info, data, data_tag, events, event_id, metadata, tmin, tmax,
#    3249  baseline, selection, drop_log, epoch_shape, cals,
#    3250  reject_params, fmt, annotations, raw_sfreq) = \
#    3251     _read_one_epoch_file(fid, tree, preload)
#
# File <decorator-gen-7>:12, in fiff_open(fname, preload, verbose)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/io/open.py:126, in fiff_open(fname, preload, verbose)
#     124 fid = _fiff_get_fid(fname)
#     125 try:
# --> 126     return _fiff_open(fname, fid, preload)
#     127 except Exception:
#     128     fid.close()
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/io/open.py:138, in _fiff_open(fname, fid, preload)
#     134 if preload:
#     135     # note that StringIO objects instantiated this way are read-only,
#     136     # but that's okay here since we are using mode "rb" anyway
#     137     with fid as fid_old:
# --> 138         fid = BytesIO(fid_old.read())
#     140 tag = read_tag_info(fid)
#     142 #   Check that this looks like a fif file
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/gzip.py:301, in GzipFile.read(self, size)
#     299     import errno
#     300     raise OSError(errno.EBADF, "read() on write-only GzipFile object")
# --> 301 return self._buffer.read(size)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/_compression.py:118, in DecompressReader.readall(self)
#     114 chunks = []
#     115 # sys.maxsize means the max length of output buffer is unlimited,
#     116 # so that the whole input buffer can be decompressed within one
#     117 # .decompress() call.
# --> 118 while data := self.read(sys.maxsize):
#     119     chunks.append(data)
#     121 return b"".join(chunks)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/gzip.py:494, in _GzipReader.read(self, size)
#     491     self._new_member = False
#     493 # Read a chunk of data from the file
# --> 494 buf = self._fp.read(io.DEFAULT_BUFFER_SIZE)
#     496 uncompress = self._decompressor.decompress(buf, size)
#     497 if self._decompressor.unconsumed_tail != b"":
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/gzip.py:88, in _PaddedFile.read(self, size)
#      86 def read(self, size):
#      87     if self._read is None:
# ---> 88         return self.file.read(size)
#      89     if self._read + size <= self._length:
#      90         read = self._read
#
# KeyboardInterrupt:

# %%
# check outputs
SUB = '2'
pd.read_pickle(f"{DERIV_ROOT}/coherence/subj-{SUB}_task-{TASK}_run-{RUN}_coh-by-condition.pkl")
# Out:
#      index sub cond  chan        50       100       150       200       250
# 0        0   2   50     1  0.057054  0.022425  0.018346  0.037030  0.034936
# 1        1   2   50     2  0.270311  0.114210  0.020435  0.024664  0.017890
# 2        2   2   50     3  0.069928  0.074090  0.028692  0.016399  0.037427
# 3        3   2   50     4  0.068576  0.023934  0.013772  0.048293  0.029126
# 4        4   2   50     5  0.143180  0.060906  0.027298  0.023254  0.015972
# ..     ...  ..  ...   ...       ...       ...       ...       ...       ...
# 305     57   2  250    58  0.069097  0.021610  0.063150  0.050554  0.116737
# 306     58   2  250    59  0.050930  0.046036  0.017001  0.044183  0.136890
# 307     59   2  250    60  0.077432  0.020853  0.031650  0.025663  0.156260
# 308     60   2  250    61  0.030675  0.031319  0.032043  0.039564  0.223008
# 309     61   2  250    62  0.057597  0.029890  0.028137  0.022597  0.416837
#
# [310 rows x 9 columns]

# %%
# import mne
# import sys
# import numpy as np
# import pandas as pd
# import matplotlib.pyplot as plt
from mne_bids import BIDSPath, read_raw_bids
from bids import BIDSLayout
# from mne_connectivity import seed_target_indices, spectral_connectivity_time, spectral_connectivity_epochs
from util.io.coherence import *
from util.io.iter_BIDSPaths import *
from util.io.preprocessing import *

# %%
SUB = 9
TASK = 'pitch'
RUN = 1
BIDS_ROOT = '../data/bids'
FIGS_ROOT = '../figs'
DERIV_ROOT = '../data/bids/derivatives'
FS = 5000
RAW_TMIN = -0.2
RAW_TMAX = 0.5
TMIN = 0
TMAX = 0.25
N_CHANS = 62
CONDS = ['50', '100', '150', '200', '250']

# Subjects from which to generate stim signal
STIM_SUB = 9
STIM_RUN = 1

# %%
layout = BIDSLayout(BIDS_ROOT, derivatives = True)
fpaths = layout.get(scope = 'preprocessing',
                    res = 'hi',
                    suffix='epo',
                    extension = 'fif.gz',
                    return_type = 'filename')
# Out:
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/bids/layout/validation.py:151: UserWarning: The PipelineDescription field was superseded by GeneratedBy in BIDS 1.4.0. You can use ``pybids upgrade`` to update your derivative dataset.
#   warnings.warn("The PipelineDescription field was superseded "

# %%
epochs = mne.read_epochs(fpaths[11], preload = True)
events = epochs.events
n_epochs = len(events)
# Out:
# Reading /project2/hcn1/pitch_tracking/scripts/../data/bids/derivatives/preprocessing/sub-10/sub-10_task-pitch_run-1_res-hi_desc-clean_epo.fif.gz ...
#     Found the data of interest:
#         t =    -200.00 ...     250.00 ms
#         0 CTF compensation matrices available
# 0 bad epochs dropped
# Not setting metadata
# 3841 matching events found
# No baseline correction applied
# 0 projection items activated

# %% [markdown]
# ### Simulate channels with stim signals

# %%
# Create epochs from raw data to create simulated stim channels
raw_epochs = get_raw_epochs(BIDS_ROOT, STIM_SUB, TASK, STIM_RUN, events)
stim_epochs_array = create_stim_epochs_array(raw_epochs, n_epochs, CONDS)
simulated_epochs = create_stim_epochs_object(stim_epochs_array, events, CONDS, FS, RAW_TMIN)

# Crop data so both epochs have same windowing
simulated_epochs = simulated_epochs.crop(tmin = TMIN, tmax = TMAX)
epochs = epochs.crop(tmin = TMIN)

# Add simulated channels to data
combined_epochs = mne.epochs.add_channels_epochs([epochs, simulated_epochs])
# Out:
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 3841 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 762 events and 3501 original time points ...
# /project2/hcn1/pitch_tracking/scripts/util/io/coherence.py:18: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /project2/hcn1/pitch_tracking/scripts/util/io/coherence.py:18: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 760 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 773 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 777 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 769 events and 3501 original time points ...
# 0 bad epochs dropped
# Not setting metadata
# 3841 matching events found
# Applying baseline correction (mode: mean)
# 0 projection items activated
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/io/meas_info.py:864: UserWarning: Avoid manually setting custom_ref_applied cannot be set directly. Please use method inst.set_eeg_reference() instead.
#   warnings.warn(f"Avoid manually setting {self._attributes[key]}")
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/io/meas_info.py:864: UserWarning: Avoid manually setting highpass cannot be set directly. Please use method inst.filter() instead.
#   warnings.warn(f"Avoid manually setting {self._attributes[key]}")
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/io/meas_info.py:864: UserWarning: Avoid manually setting lowpass cannot be set directly. Please use method inst.filter() instead.
#   warnings.warn(f"Avoid manually setting {self._attributes[key]}")
# 0 bad epochs dropped

# %%
# Plot the stim signals
n_samples = np.shape(stim_epochs_array)[2]
t = np.linspace(RAW_TMIN, RAW_TMAX, n_samples, endpoint = False)

fig, axs = plt.subplots(5)
axs[0].plot(t, stim_epochs_array[0, 0, :])
axs[1].plot(t, stim_epochs_array[0, 1, :])
axs[2].plot(t, stim_epochs_array[0, 2, :])
axs[3].plot(t, stim_epochs_array[0, 3, :])
axs[4].plot(t, stim_epochs_array[0, 4, :])

# %% [markdown]
# ### Compute coherence

# %%
indices = get_coh_indices(N_CHANS)
fmin, fmax = get_fmin_and_fmax(CONDS)
coh_df = pd.DataFrame()
for cond in CONDS:
    coh = get_coh(cond, combined_epochs, indices, fmin, fmax, CONDS, FS)
    coh = clean_coh(coh, N_CHANS)
    cond_coh_df = create_coh_df(coh, cond, CONDS, N_CHANS, SUB)
    coh_df = pd.concat([coh_df, cond_coh_df])
coh_df = coh_df.reset_index()
# Out:
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
#     computing connectivity for epoch 368
#     computing connectivity for epoch 369
#     computing connectivity for epoch 370
#     computing connectivity for epoch 371
#     computing connectivity for epoch 372
#     computing connectivity for epoch 373
#     computing connectivity for epoch 374
#     computing connectivity for epoch 375
# [Connectivity computation done]
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
#     computing connectivity for epoch 368
#     computing connectivity for epoch 369
#     computing connectivity for epoch 370
#     computing connectivity for epoch 371
#     computing connectivity for epoch 372
#     computing connectivity for epoch 373
#     computing connectivity for epoch 374
#     computing connectivity for epoch 375
#     computing connectivity for epoch 376
#     computing connectivity for epoch 377
#     computing connectivity for epoch 378
#     computing connectivity for epoch 379
#     computing connectivity for epoch 380
#     computing connectivity for epoch 381
#     computing connectivity for epoch 382
#     computing connectivity for epoch 383
#     computing connectivity for epoch 384
#     computing connectivity for epoch 385
#     computing connectivity for epoch 386
#     computing connectivity for epoch 387
#     computing connectivity for epoch 388
#     computing connectivity for epoch 389
#     computing connectivity for epoch 390
#     computing connectivity for epoch 391
#     computing connectivity for epoch 392
#     computing connectivity for epoch 393
# [Connectivity computation done]
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
# ...
#     computing connectivity for epoch 383
#     computing connectivity for epoch 384
#     computing connectivity for epoch 385
#     computing connectivity for epoch 386
#     computing connectivity for epoch 387
#     computing connectivity for epoch 388
#     computing connectivity for epoch 389
#     computing connectivity for epoch 390
#     computing connectivity for epoch 391
#     computing connectivity for epoch 392
# [Connectivity computation done]
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
# [Connectivity computation done]

# %%
coh_df = coh_df.reset_index()
coh_df
# Out:
#      index  sub cond  chan        50       100       150       200       250
# 0        0    9   50     1  0.103250  0.061759  0.030829  0.061679  0.055187
# 1        1    9   50     2  0.150494  0.034989  0.054653  0.065363  0.031277
# 2        2    9   50     3  0.044568  0.046067  0.060875  0.059236  0.029454
# 3        3    9   50     4  0.097713  0.049817  0.036001  0.053279  0.031313
# 4        4    9   50     5  0.012519  0.026121  0.049547  0.048568  0.031164
# ..     ...  ...  ...   ...       ...       ...       ...       ...       ...
# 305     57    9  250    58  0.091086  0.023705  0.029659  0.027425  0.024792
# 306     58    9  250    59  0.073659  0.028758  0.037821  0.029000  0.224433
# 307     59    9  250    60  0.081519  0.034063  0.051116  0.027132  0.266214
# 308     60    9  250    61  0.027993  0.047640  0.060025  0.046211  0.405855
# 309     61    9  250    62  0.055068  0.057153  0.033150  0.043684  0.466430
#
# [310 rows x 9 columns]

# %%
# def get_raw_epochs(BIDS_ROOT, sub, task, run):
#     sub = str(sub)
#     run = str(run)
#     bids_path = BIDSPath(root = BIDS_ROOT,
#                      subject = sub,
#                      task = task,
#                      run = run,
#                      datatype = 'eeg')
#     raw = read_raw_bids(bids_path, verbose = False)
#     raw_events, raw_event_id = mne.events_from_annotations(raw)
#     raw_epochs = mne.Epochs(raw, 
#                     events = raw_events, 
#                     baseline = None,
#                     event_id = raw_event_id)
#     return(raw_epochs)

# # LOOK AT SIMULATED STIM CHANS FOR ALL SUBS
# BIDS_ROOT = '../data/bids'
# DERIV_ROOT = '../data/bids/derivatives'
# layout = BIDSLayout(BIDS_ROOT, derivatives = False)
# fpaths = layout.get(extension = 'eeg',
#                     return_type = 'filename')

# for (FPATH, SUB, TASK, RUN) in iter_BIDSPaths(fpaths):
#     if SUB == '2':
#         continue
#     raw_epochs = get_raw_epochs(BIDS_ROOT, SUB, TASK, RUN)
#     raw_epochs.load_data()
#     raw_epochs.plot(picks = 'stim')
# Out:
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-2/eeg/sub-2_task-pitch_run-1_eeg.eeg', '2', 'pitch', '1')
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-3/eeg/sub-3_task-pitch_run-1_eeg.eeg', '3', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 2400 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 2400 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Using matplotlib as 2D backend.
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-3/eeg/sub-3_task-pitch_run-2_eeg.eeg', '3', 'pitch', '2')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 2400 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 2400 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-4/eeg/sub-4_task-pitch_run-1_eeg.eeg', '4', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 2461 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 2461 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Ch64', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-4/eeg/sub-4_task-pitch_run-2_eeg.eeg', '4', 'pitch', '2')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 2400 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 2400 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Ch64', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# Unexpected exception formatting exception. Falling back to standard exception
# Traceback (most recent call last):
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 3398, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "/tmp/ipykernel_53153/891457072.py", line 28, in <cell line: 24>
#     raw_epochs.load_data()
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/epochs.py", line 644, in load_data
#     self._data = self._get_data()
#   File "<decorator-gen-249>", line 12, in _get_data
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/epochs.py", line -1, in _get_data
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/interactiveshell.py", line 1993, in showtraceback
#     stb = self.InteractiveTB.structured_traceback(
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1118, in structured_traceback
#     return FormattedTB.structured_traceback(
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/ultratb.py", line 1012, in structured_traceback
#     return VerboseTB.structured_traceback(
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/ultratb.py", line 865, in structured_traceback
#     formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/ultratb.py", line 818, in format_exception_as_a_whole
#     frames.append(self.format_record(r))
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/ultratb.py", line 736, in format_record
#     result += ''.join(_format_traceback_lines(frame_info.lines, Colors, self.has_colors, lvals))
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/stack_data/core.py", line 698, in lines
#     pieces = self.included_pieces
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/stack_data/core.py", line 649, in included_pieces
#     pos = scope_pieces.index(self.executing_piece)
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/stack_data/utils.py", line 145, in cached_property_wrapper
#     value = obj.__dict__[self.func.__name__] = self.func(obj)
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/stack_data/core.py", line 628, in executing_piece
#     return only(
#   File "/home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/executing/executing.py", line 164, in only
#     raise NotOneValueFound('Expected one value, found 0')
# executing.executing.NotOneValueFound: Expected one value, found 0

# %%
# LOOK AT SIMULATED STIM CHANS FOR ALL SUBS
layout = BIDSLayout(BIDS_ROOT, derivatives = True)
# fpaths = layout.get(scope = 'preprocessing',
#                 res = 'hi',
#                 suffix='epo',
#                 extension = 'fif.gz',
#                 return_type = 'filename')
fpaths = layout.get(extension = 'eeg',
                    return_type = 'filename')

for (FPATH, SUB, TASK, RUN) in iter_BIDSPaths(fpaths):
    if SUB == '2':
        continue
    n_epochs = 1
    
    # Create epochs from raw data to create simulated stim channels
    raw_epochs = get_raw_epochs(BIDS_ROOT, SUB, TASK, RUN)
    stim_epochs_array = create_stim_epochs_array(raw_epochs, n_epochs, CONDS)

    # Plot the stim signals
    n_samples = np.shape(stim_epochs_array)[2]
    t = np.linspace(RAW_TMIN, RAW_TMAX, n_samples, endpoint = False)

    fig, axs = plt.subplots(2)
    axs[0].plot(t, stim_epochs_array[0, 0, :])
    axs[1].plot(t, stim_epochs_array[0, 1, :])
    plt.show()
    
    raw_epochs.load_data()
    raw_epochs.plot(picks = 'stim')
# Out:
# /home/letitiayhho/.conda/envs/pitch-tracking/lib/python3.10/site-packages/bids/layout/validation.py:151: UserWarning: The PipelineDescription field was superseded by GeneratedBy in BIDS 1.4.0. You can use ``pybids upgrade`` to update your derivative dataset.
#   warnings.warn("The PipelineDescription field was superseded "
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-2/eeg/sub-2_task-pitch_run-1_eeg.eeg', '2', 'pitch', '1')
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-3/eeg/sub-3_task-pitch_run-1_eeg.eeg', '3', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 2400 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 478 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 447 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 500 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 483 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 492 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 2400 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-3/eeg/sub-3_task-pitch_run-2_eeg.eeg', '3', 'pitch', '2')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 2400 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 503 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 480 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 504 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 442 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 471 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 2400 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-4/eeg/sub-4_task-pitch_run-1_eeg.eeg', '4', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 2461 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 512 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Ch64', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 479 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 505 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 498 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 467 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 2461 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-4/eeg/sub-4_task-pitch_run-2_eeg.eeg', '4', 'pitch', '2')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 2400 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 493 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Ch64', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 489 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 469 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 485 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 464 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 2400 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-5/eeg/sub-5_task-pitch_run-1_eeg.eeg', '5', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 4800 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 973 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 923 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 1009 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 957 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 938 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 4800 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-6/eeg/sub-6_task-pitch_run-1_eeg.eeg', '6', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 4800 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 975 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 897 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 965 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 957 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 1006 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 4800 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-7/eeg/sub-7_task-pitch_run-1_eeg.eeg', '7', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 4800 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 969 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 940 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 1002 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 961 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 928 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 4800 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-8/eeg/sub-8_task-pitch_run-1_eeg.eeg', '8', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 4800 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 924 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 969 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 957 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 937 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 1013 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 4800 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-9/eeg/sub-9_task-pitch_run-1_eeg.eeg', '9', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 2400 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 470 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 489 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 491 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 480 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 470 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 2400 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# <MNEBrowseFigure size 576x576 with 4 Axes>
# ('/project2/hcn1/pitch_tracking/scripts/../data/bids/sub-10/eeg/sub-10_task-pitch_run-1_eeg.eeg', '10', 'pitch', '1')
# Used Annotations descriptions: ['100', '150', '200', '250', '50']
# Not setting metadata
# 4800 matching events found
# No baseline correction applied
# 0 projection items activated
# Loading data for 944 events and 3501 original time points ...
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: There are channels without locations (n/a) that are not marked as bad: ['leog', 'reog', 'Aux1']
#   raw = read_raw_bids(bids_path, verbose = False)
# /tmp/ipykernel_53153/891457072.py:9: RuntimeWarning: Not setting position of 1 stim channel found in montage:
# ['Aux1']
# Consider setting the channel types to be of EEG/sEEG/ECoG/DBS/fNIRS using inst.set_channel_types before calling inst.set_montage, or omit these channels when creating your montage.
#   raw = read_raw_bids(bids_path, verbose = False)
# 0 bad epochs dropped
# Loading data for 956 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 967 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 964 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 969 events and 3501 original time points ...
# 0 bad epochs dropped
# Loading data for 4800 events and 3501 original time points ...
# 0 bad epochs dropped
# Opening epochs-browser...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Input In [52], in <cell line: 11>()
#      27 plt.show()
#      29 raw_epochs.load_data()
# ---> 30 raw_epochs.plot(picks = 'stim')
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/epochs.py:1167, in BaseEpochs.plot(self, picks, scalings, n_epochs, n_channels, title, events, event_color, order, show, block, decim, noise_cov, butterfly, show_scrollbars, show_scalebars, epoch_colors, event_id, group_by, precompute, use_opengl, theme)
#    1160 @copy_function_doc_to_method_doc(plot_epochs)
#    1161 def plot(self, picks=None, scalings=None, n_epochs=20, n_channels=20,
#    1162          title=None, events=None, event_color=None,
#    (...)
#    1165          epoch_colors=None, event_id=None, group_by='type',
#    1166          precompute=None, use_opengl=None, *, theme=None):
# -> 1167     return plot_epochs(self, picks=picks, scalings=scalings,
#    1168                        n_epochs=n_epochs, n_channels=n_channels,
#    1169                        title=title, events=events, event_color=event_color,
#    1170                        order=order, show=show, block=block, decim=decim,
#    1171                        noise_cov=noise_cov, butterfly=butterfly,
#    1172                        show_scrollbars=show_scrollbars,
#    1173                        show_scalebars=show_scalebars,
#    1174                        epoch_colors=epoch_colors, event_id=event_id,
#    1175                        group_by=group_by, precompute=precompute,
#    1176                        use_opengl=use_opengl, theme=theme)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/viz/epochs.py:912, in plot_epochs(epochs, picks, scalings, n_epochs, n_channels, title, events, event_color, order, show, block, decim, noise_cov, butterfly, show_scrollbars, show_scalebars, epoch_colors, event_id, group_by, precompute, use_opengl, theme)
#     857 precompute = _handle_precompute(precompute)
#     858 params = dict(inst=epochs,
#     859               info=info,
#     860               n_epochs=n_epochs,
#    (...)
#     909               precompute=precompute,
#     910               use_opengl=use_opengl)
# --> 912 fig = _get_browser(show=show, block=block, **params)
#     914 return fig
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/viz/_figure.py:655, in _get_browser(show, block, **kwargs)
#     653 # Initialize Browser
#     654 fig = backend._init_browser(**kwargs)
# --> 655 _show_browser(show=show, block=block, fig=fig)
#     657 return fig
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/viz/utils.py:144, in _show_browser(show, block, fig, **kwargs)
#     142     block = False
#     143 if backend == 'matplotlib':
# --> 144     plt_show(show, block=block, **kwargs)
#     145 else:
#     146     from PyQt5.QtWidgets import QApplication
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne/viz/utils.py:120, in plt_show(show, fig, **kwargs)
#     118 import matplotlib.pyplot as plt
#     119 if show and get_backend() != 'agg':
# --> 120     (fig or plt).show(**kwargs)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/pyplot.py:368, in show(*args, **kwargs)
#     324 """
#     325 Display all open figures.
#     326
#    (...)
#     365 explicitly there.
#     366 """
#     367 _warn_if_gui_out_of_main_thread()
# --> 368 return _backend_mod.show(*args, **kwargs)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib_inline/backend_inline.py:41, in show(close, block)
#      39 try:
#      40     for figure_manager in Gcf.get_all_fig_managers():
# ---> 41         display(
#      42             figure_manager.canvas.figure,
#      43             metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#      44         )
#      45 finally:
#      46     show._to_draw = []
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/display_functions.py:298, in display(include, exclude, metadata, transient, display_id, raw, clear, *objs, **kwargs)
#     296     publish_display_data(data=obj, metadata=metadata, **kwargs)
#     297 else:
# --> 298     format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     299     if not format_dict:
#     300         # nothing to display (e.g. _ipython_display_ took over)
#     301         continue
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/formatters.py:178, in DisplayFormatter.format(self, obj, include, exclude)
#     176 md = None
#     177 try:
# --> 178     data = formatter(obj)
#     179 except:
#     180     # FIXME: log the exception
#     181     raise
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/decorator.py:232, in decorate.<locals>.fun(*args, **kw)
#     230 if not kwsyntax:
#     231     args, kw = fix(args, kw, sig)
# --> 232 return caller(func, *(extras + args), **kw)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/formatters.py:222, in catch_format_error(method, self, *args, **kwargs)
#     220 """show traceback on failed format call"""
#     221 try:
# --> 222     r = method(self, *args, **kwargs)
#     223 except NotImplementedError:
#     224     # don't warn on NotImplementedErrors
#     225     return self._check_return(None, args[0])
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/formatters.py:339, in BaseFormatter.__call__(self, obj)
#     337     pass
#     338 else:
# --> 339     return printer(obj)
#     340 # Finally look for special method names
#     341 method = get_real_method(obj, self.print_method)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/IPython/core/pylabtools.py:151, in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     148     from matplotlib.backend_bases import FigureCanvasBase
#     149     FigureCanvasBase(fig)
# --> 151 fig.canvas.print_figure(bytes_io, **kw)
#     152 data = bytes_io.getvalue()
#     153 if fmt == 'svg':
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/backend_bases.py:2319, in FigureCanvasBase.print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2315 try:
#    2316     # _get_renderer may change the figure dpi (as vector formats
#    2317     # force the figure dpi to 72), so we need to set it again here.
#    2318     with cbook._setattr_cm(self.figure, dpi=dpi):
# -> 2319         result = print_method(
#    2320             filename,
#    2321             facecolor=facecolor,
#    2322             edgecolor=edgecolor,
#    2323             orientation=orientation,
#    2324             bbox_inches_restore=_bbox_inches_restore,
#    2325             **kwargs)
#    2326 finally:
#    2327     if bbox_inches and restore_bbox:
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/backend_bases.py:1648, in _check_savefig_extra_args.<locals>.wrapper(*args, **kwargs)
#    1640     _api.warn_deprecated(
#    1641         '3.3', name=name, removal='3.6',
#    1642         message='%(name)s() got unexpected keyword argument "'
#    1643                 + arg + '" which is no longer supported as of '
#    1644                 '%(since)s and will become an error '
#    1645                 '%(removal)s')
#    1646     kwargs.pop(arg)
# -> 1648 return func(*args, **kwargs)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/_api/deprecation.py:412, in delete_parameter.<locals>.wrapper(*inner_args, **inner_kwargs)
#     402     deprecation_addendum = (
#     403         f"If any parameter follows {name!r}, they should be passed as "
#     404         f"keyword, not positionally.")
#     405     warn_deprecated(
#     406         since,
#     407         name=repr(name),
#    (...)
#     410                  else deprecation_addendum,
#     411         **kwargs)
# --> 412 return func(*inner_args, **inner_kwargs)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:540, in FigureCanvasAgg.print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     490 @_check_savefig_extra_args
#     491 @_api.delete_parameter("3.5", "args")
#     492 def print_png(self, filename_or_obj, *args,
#     493               metadata=None, pil_kwargs=None):
#     494     """
#     495     Write the figure to a PNG file.
#     496
#    (...)
#     538         *metadata*, including the default 'Software' key.
#     539     """
# --> 540     FigureCanvasAgg.draw(self)
#     541     mpl.image.imsave(
#     542         filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     543         dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/backends/backend_agg.py:436, in FigureCanvasAgg.draw(self)
#     432 # Acquire a lock on the shared font cache.
#     433 with RendererAgg.lock, \
#     434      (self.toolbar._wait_cursor_for_draw_cm() if self.toolbar
#     435       else nullcontext()):
# --> 436     self.figure.draw(self.renderer)
#     437     # A GUI class may be need to update a window using this draw, so
#     438     # don't forget to call the superclass.
#     439     super().draw()
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/artist.py:73, in _finalize_rasterization.<locals>.draw_wrapper(artist, renderer, *args, **kwargs)
#      71 @wraps(draw)
#      72 def draw_wrapper(artist, renderer, *args, **kwargs):
# ---> 73     result = draw(artist, renderer, *args, **kwargs)
#      74     if renderer._rasterizing:
#      75         renderer.stop_rasterizing()
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/figure.py:2810, in Figure.draw(self, renderer)
#    2807         # ValueError can occur when resizing a window.
#    2809 self.patch.draw(renderer)
# -> 2810 mimage._draw_list_compositing_images(
#    2811     renderer, self, artists, self.suppressComposite)
#    2813 for sfig in self.subfigs:
#    2814     sfig.draw(renderer)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/axes/_base.py:3082, in _AxesBase.draw(self, renderer)
#    3079         a.draw(renderer)
#    3080     renderer.stop_rasterizing()
# -> 3082 mimage._draw_list_compositing_images(
#    3083     renderer, self, artists, self.figure.suppressComposite)
#    3085 renderer.close_group('axes')
#    3086 self.stale = False
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/image.py:132, in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     130 if not_composite or not has_images:
#     131     for a in artists:
# --> 132         a.draw(renderer)
#     133 else:
#     134     # Composite any adjacent images together
#     135     image_group = []
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/axis.py:1163, in Axis.draw(self, renderer, *args, **kwargs)
#    1159 ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1160                                                         renderer)
#    1162 for tick in ticks_to_draw:
# -> 1163     tick.draw(renderer)
#    1165 # scale up the axis label box to also find the neighbors, not
#    1166 # just the tick labels that actually overlap note we need a
#    1167 # *copy* of the axis label box because we don't want to scale
#    1168 # the actual bbox
#    1170 self._update_label_position(renderer)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/artist.py:50, in allow_rasterization.<locals>.draw_wrapper(artist, renderer)
#      47     if artist.get_agg_filter() is not None:
#      48         renderer.start_filter()
# ---> 50     return draw(artist, renderer)
#      51 finally:
#      52     if artist.get_agg_filter() is not None:
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/matplotlib/axis.py:299, in Tick.draw(self, renderer)
#     296 renderer.open_group(self.__name__, gid=self.get_gid())
#     297 for artist in [self.gridline, self.tick1line, self.tick2line,
#     298                self.label1, self.label2]:
# --> 299     artist.draw(renderer)
#     300 renderer.close_group(self.__name__)
#     301 self.stale = False
#
# KeyboardInterrupt:

# %%
raw_epochs.info
# Out:
# <Info | 12 non-empty values
#  bads: []
#  ch_names: Fp1, Fz, F3, F7, FT9, FC5, FC1, C3, T7, TP9, CP5, CP1, Pz, P3, ...
#  chs: 64 EEG, 1 Stimulus
#  custom_ref_applied: False
#  description: Anonymized using a time shift to preserve age at acquisition
#  dig: 64 items (64 EEG)
#  experimenter: mne_anonymize
#  highpass: 0.0 Hz
#  line_freq: 60.0
#  lowpass: 5000.0 Hz
#  meas_date: 1924-12-31 16:03:30 UTC
#  nchan: 65
#  projs: []
#  sfreq: 10000.0 Hz
#  subject_info: 4 items (dict)
# >

# %%
# # Set indices of channel pairs to compute coherence across
# stim_indices = np.array([63, 64, 65, 66, 67]*N_CHANS)
# chan_indices = np.repeat(np.arange(1, 63, 1), 5)
# indices = (stim_indices, chan_indices)

# %%
# # Set freqs to compute coherence at
# freqs = np.array([50, 100, 150, 200, 250])
# fmin = freqs - 5
# fmax = freqs + 5

# %%
# def get_coh(cond, epochs, indices, CONDS, FS):
#     coh = spectral_connectivity_epochs(
#         combined_epochs[cond], method='coh', mode='fourier', indices=indices,
#         sfreq=FS, fmin=fmin, fmax=fmax, faverage=True, n_jobs=1, verbose = 'WARNING')
#     return(coh)

# def clean_coh(coh, N_CHANS):
#     df = np.zeros((N_CHANS, 5))
#     coh_vals = coh.get_data()
#     for i in range(310):
#         a = i
#         b = a%5
#         chan = int(i/5)
#         val = coh_vals[a, b]
#         df[chan, b] = val
#     return(df)

# def create_coh_df(coh, cond, CONDS, N_CHANS, SUB):
#     coh_df = pd.DataFrame(data = coh, 
#                           columns = CONDS)
#     coh_df.insert(0, 'chan', list(range(1, N_CHANS+1)))
#     coh_df.insert(0, 'cond', np.array([cond]*N_CHANS))
#     coh_df.insert(0, 'sub', np.array([SUB]*N_CHANS))
#     return(coh_df)

# Run coherence for each condition
coh_df = pd.DataFrame()
for cond in CONDS:
    coh = get_coh(cond, combined_epochs, indices, fmin, fmax, FS)
    coh = clean_coh(coh, N_CHANS)
    cond_coh_df = create_coh_df(coh, cond, CONDS, N_CHANS, SUB)
    coh_df = pd.concat([coh_df, cond_coh_df])
# Out:
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
#     computing connectivity for epoch 368
#     computing connectivity for epoch 369
#     computing connectivity for epoch 370
#     computing connectivity for epoch 371
#     computing connectivity for epoch 372
#     computing connectivity for epoch 373
#     computing connectivity for epoch 374
#     computing connectivity for epoch 375
# [Connectivity computation done]
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
#     computing connectivity for epoch 368
#     computing connectivity for epoch 369
#     computing connectivity for epoch 370
#     computing connectivity for epoch 371
#     computing connectivity for epoch 372
#     computing connectivity for epoch 373
#     computing connectivity for epoch 374
#     computing connectivity for epoch 375
#     computing connectivity for epoch 376
#     computing connectivity for epoch 377
#     computing connectivity for epoch 378
#     computing connectivity for epoch 379
#     computing connectivity for epoch 380
#     computing connectivity for epoch 381
#     computing connectivity for epoch 382
#     computing connectivity for epoch 383
#     computing connectivity for epoch 384
#     computing connectivity for epoch 385
#     computing connectivity for epoch 386
#     computing connectivity for epoch 387
#     computing connectivity for epoch 388
#     computing connectivity for epoch 389
#     computing connectivity for epoch 390
#     computing connectivity for epoch 391
#     computing connectivity for epoch 392
#     computing connectivity for epoch 393
# [Connectivity computation done]
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
# ...
#     computing connectivity for epoch 383
#     computing connectivity for epoch 384
#     computing connectivity for epoch 385
#     computing connectivity for epoch 386
#     computing connectivity for epoch 387
#     computing connectivity for epoch 388
#     computing connectivity for epoch 389
#     computing connectivity for epoch 390
#     computing connectivity for epoch 391
#     computing connectivity for epoch 392
# [Connectivity computation done]
# Adding metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
# [Connectivity computation done]

# %%
# coh_df.insert(0, 'chan', list(range(1, N_CHANS+1)))
# coh_df
# coh_df
# Out:
#     sub cond  chan        50       100       150       200       250
# 0     9   50     1  0.103250  0.061759  0.030829  0.061679  0.055187
# 1     9   50     2  0.150494  0.034989  0.054653  0.065363  0.031277
# 2     9   50     3  0.044568  0.046067  0.060875  0.059236  0.029454
# 3     9   50     4  0.097713  0.049817  0.036001  0.053279  0.031313
# 4     9   50     5  0.012519  0.026121  0.049547  0.048568  0.031164
# ..  ...  ...   ...       ...       ...       ...       ...       ...
# 57    9  250    58  0.091086  0.023705  0.029659  0.027425  0.024792
# 58    9  250    59  0.073659  0.028758  0.037821  0.029000  0.224433
# 59    9  250    60  0.081519  0.034063  0.051116  0.027132  0.266214
# 60    9  250    61  0.027993  0.047640  0.060025  0.046211  0.405855
# 61    9  250    62  0.055068  0.057153  0.033150  0.043684  0.466430
#
# [310 rows x 8 columns]

# %%
# coh = spectral_connectivity_epochs(
#     combined_epochs, method='coh', mode='fourier', indices=indices,
#     sfreq=FS, fmin=fmin, fmax=fmax, faverage=True, n_jobs=1)
# freqs = coh.freqs

# print('Frequencies in Hz over which coherence was averaged for 50 Hz: ')
# print(freqs[0])
# print('Frequencies in Hz over which coherence was averaged for 100 Hz: ')
# print(freqs[1])
# print('Frequencies in Hz over which coherence was averaged for 150 Hz: ')
# print(freqs[2])
# print('Frequencies in Hz over which coherence was averaged for 200 Hz: ')
# print(freqs[3])
# print('Frequencies in Hz over which coherence was averaged for 250 Hz: ')
# print(freqs[4])
# Out:
# Replacing existing metadata with 3 columns
# Connectivity computation...
#     computing connectivity for 310 connections
#     using t=0.000s..0.250s for estimation (1251 points)
#     computing connectivity for the bands:
#      band 1: 48.0Hz..52.0Hz (2 points)
#      band 2: 95.9Hz..103.9Hz (3 points)
#      band 3: 147.9Hz..151.9Hz (2 points)
#      band 4: 195.8Hz..203.8Hz (3 points)
#      band 5: 247.8Hz..251.8Hz (2 points)
#     connectivity scores will be averaged for each band
#     using FFT with a Hanning window to estimate spectra
#     the following metrics will be computed: Coherence
#     computing connectivity for epoch 1
#     computing connectivity for epoch 2
#     computing connectivity for epoch 3
#     computing connectivity for epoch 4
#     computing connectivity for epoch 5
#     computing connectivity for epoch 6
#     computing connectivity for epoch 7
#     computing connectivity for epoch 8
#     computing connectivity for epoch 9
#     computing connectivity for epoch 10
#     computing connectivity for epoch 11
#     computing connectivity for epoch 12
#     computing connectivity for epoch 13
#     computing connectivity for epoch 14
#     computing connectivity for epoch 15
#     computing connectivity for epoch 16
#     computing connectivity for epoch 17
#     computing connectivity for epoch 18
#     computing connectivity for epoch 19
#     computing connectivity for epoch 20
#     computing connectivity for epoch 21
#     computing connectivity for epoch 22
#     computing connectivity for epoch 23
#     computing connectivity for epoch 24
#     computing connectivity for epoch 25
#     computing connectivity for epoch 26
#     computing connectivity for epoch 27
#     computing connectivity for epoch 28
#     computing connectivity for epoch 29
#     computing connectivity for epoch 30
#     computing connectivity for epoch 31
#     computing connectivity for epoch 32
#     computing connectivity for epoch 33
#     computing connectivity for epoch 34
#     computing connectivity for epoch 35
#     computing connectivity for epoch 36
#     computing connectivity for epoch 37
#     computing connectivity for epoch 38
#     computing connectivity for epoch 39
#     computing connectivity for epoch 40
#     computing connectivity for epoch 41
#     computing connectivity for epoch 42
#     computing connectivity for epoch 43
#     computing connectivity for epoch 44
#     computing connectivity for epoch 45
#     computing connectivity for epoch 46
#     computing connectivity for epoch 47
#     computing connectivity for epoch 48
#     computing connectivity for epoch 49
#     computing connectivity for epoch 50
#     computing connectivity for epoch 51
#     computing connectivity for epoch 52
#     computing connectivity for epoch 53
#     computing connectivity for epoch 54
#     computing connectivity for epoch 55
#     computing connectivity for epoch 56
#     computing connectivity for epoch 57
#     computing connectivity for epoch 58
#     computing connectivity for epoch 59
#     computing connectivity for epoch 60
#     computing connectivity for epoch 61
#     computing connectivity for epoch 62
#     computing connectivity for epoch 63
#     computing connectivity for epoch 64
#     computing connectivity for epoch 65
#     computing connectivity for epoch 66
#     computing connectivity for epoch 67
#     computing connectivity for epoch 68
#     computing connectivity for epoch 69
#     computing connectivity for epoch 70
#     computing connectivity for epoch 71
#     computing connectivity for epoch 72
#     computing connectivity for epoch 73
#     computing connectivity for epoch 74
#     computing connectivity for epoch 75
#     computing connectivity for epoch 76
#     computing connectivity for epoch 77
#     computing connectivity for epoch 78
#     computing connectivity for epoch 79
#     computing connectivity for epoch 80
#     computing connectivity for epoch 81
#     computing connectivity for epoch 82
#     computing connectivity for epoch 83
#     computing connectivity for epoch 84
#     computing connectivity for epoch 85
#     computing connectivity for epoch 86
#     computing connectivity for epoch 87
#     computing connectivity for epoch 88
#     computing connectivity for epoch 89
#     computing connectivity for epoch 90
#     computing connectivity for epoch 91
#     computing connectivity for epoch 92
#     computing connectivity for epoch 93
#     computing connectivity for epoch 94
#     computing connectivity for epoch 95
#     computing connectivity for epoch 96
#     computing connectivity for epoch 97
#     computing connectivity for epoch 98
#     computing connectivity for epoch 99
#     computing connectivity for epoch 100
#     computing connectivity for epoch 101
#     computing connectivity for epoch 102
#     computing connectivity for epoch 103
#     computing connectivity for epoch 104
#     computing connectivity for epoch 105
#     computing connectivity for epoch 106
#     computing connectivity for epoch 107
#     computing connectivity for epoch 108
#     computing connectivity for epoch 109
#     computing connectivity for epoch 110
#     computing connectivity for epoch 111
#     computing connectivity for epoch 112
#     computing connectivity for epoch 113
#     computing connectivity for epoch 114
#     computing connectivity for epoch 115
#     computing connectivity for epoch 116
#     computing connectivity for epoch 117
#     computing connectivity for epoch 118
#     computing connectivity for epoch 119
#     computing connectivity for epoch 120
#     computing connectivity for epoch 121
#     computing connectivity for epoch 122
#     computing connectivity for epoch 123
#     computing connectivity for epoch 124
#     computing connectivity for epoch 125
#     computing connectivity for epoch 126
#     computing connectivity for epoch 127
#     computing connectivity for epoch 128
#     computing connectivity for epoch 129
#     computing connectivity for epoch 130
#     computing connectivity for epoch 131
#     computing connectivity for epoch 132
#     computing connectivity for epoch 133
#     computing connectivity for epoch 134
#     computing connectivity for epoch 135
#     computing connectivity for epoch 136
#     computing connectivity for epoch 137
#     computing connectivity for epoch 138
#     computing connectivity for epoch 139
#     computing connectivity for epoch 140
#     computing connectivity for epoch 141
#     computing connectivity for epoch 142
#     computing connectivity for epoch 143
#     computing connectivity for epoch 144
#     computing connectivity for epoch 145
#     computing connectivity for epoch 146
#     computing connectivity for epoch 147
#     computing connectivity for epoch 148
#     computing connectivity for epoch 149
#     computing connectivity for epoch 150
#     computing connectivity for epoch 151
#     computing connectivity for epoch 152
#     computing connectivity for epoch 153
#     computing connectivity for epoch 154
#     computing connectivity for epoch 155
#     computing connectivity for epoch 156
#     computing connectivity for epoch 157
#     computing connectivity for epoch 158
#     computing connectivity for epoch 159
#     computing connectivity for epoch 160
#     computing connectivity for epoch 161
#     computing connectivity for epoch 162
#     computing connectivity for epoch 163
#     computing connectivity for epoch 164
#     computing connectivity for epoch 165
#     computing connectivity for epoch 166
#     computing connectivity for epoch 167
#     computing connectivity for epoch 168
#     computing connectivity for epoch 169
#     computing connectivity for epoch 170
#     computing connectivity for epoch 171
#     computing connectivity for epoch 172
#     computing connectivity for epoch 173
#     computing connectivity for epoch 174
#     computing connectivity for epoch 175
#     computing connectivity for epoch 176
#     computing connectivity for epoch 177
#     computing connectivity for epoch 178
#     computing connectivity for epoch 179
#     computing connectivity for epoch 180
#     computing connectivity for epoch 181
#     computing connectivity for epoch 182
#     computing connectivity for epoch 183
#     computing connectivity for epoch 184
#     computing connectivity for epoch 185
#     computing connectivity for epoch 186
#     computing connectivity for epoch 187
#     computing connectivity for epoch 188
#     computing connectivity for epoch 189
#     computing connectivity for epoch 190
#     computing connectivity for epoch 191
#     computing connectivity for epoch 192
#     computing connectivity for epoch 193
#     computing connectivity for epoch 194
#     computing connectivity for epoch 195
#     computing connectivity for epoch 196
#     computing connectivity for epoch 197
#     computing connectivity for epoch 198
#     computing connectivity for epoch 199
#     computing connectivity for epoch 200
#     computing connectivity for epoch 201
#     computing connectivity for epoch 202
#     computing connectivity for epoch 203
#     computing connectivity for epoch 204
#     computing connectivity for epoch 205
#     computing connectivity for epoch 206
#     computing connectivity for epoch 207
#     computing connectivity for epoch 208
#     computing connectivity for epoch 209
#     computing connectivity for epoch 210
#     computing connectivity for epoch 211
#     computing connectivity for epoch 212
#     computing connectivity for epoch 213
#     computing connectivity for epoch 214
#     computing connectivity for epoch 215
#     computing connectivity for epoch 216
#     computing connectivity for epoch 217
#     computing connectivity for epoch 218
#     computing connectivity for epoch 219
#     computing connectivity for epoch 220
#     computing connectivity for epoch 221
#     computing connectivity for epoch 222
#     computing connectivity for epoch 223
#     computing connectivity for epoch 224
#     computing connectivity for epoch 225
#     computing connectivity for epoch 226
#     computing connectivity for epoch 227
#     computing connectivity for epoch 228
#     computing connectivity for epoch 229
#     computing connectivity for epoch 230
#     computing connectivity for epoch 231
#     computing connectivity for epoch 232
#     computing connectivity for epoch 233
#     computing connectivity for epoch 234
#     computing connectivity for epoch 235
#     computing connectivity for epoch 236
#     computing connectivity for epoch 237
#     computing connectivity for epoch 238
#     computing connectivity for epoch 239
#     computing connectivity for epoch 240
#     computing connectivity for epoch 241
#     computing connectivity for epoch 242
#     computing connectivity for epoch 243
#     computing connectivity for epoch 244
#     computing connectivity for epoch 245
#     computing connectivity for epoch 246
#     computing connectivity for epoch 247
#     computing connectivity for epoch 248
#     computing connectivity for epoch 249
#     computing connectivity for epoch 250
#     computing connectivity for epoch 251
#     computing connectivity for epoch 252
#     computing connectivity for epoch 253
#     computing connectivity for epoch 254
#     computing connectivity for epoch 255
#     computing connectivity for epoch 256
#     computing connectivity for epoch 257
#     computing connectivity for epoch 258
#     computing connectivity for epoch 259
#     computing connectivity for epoch 260
#     computing connectivity for epoch 261
#     computing connectivity for epoch 262
#     computing connectivity for epoch 263
#     computing connectivity for epoch 264
#     computing connectivity for epoch 265
#     computing connectivity for epoch 266
#     computing connectivity for epoch 267
#     computing connectivity for epoch 268
#     computing connectivity for epoch 269
#     computing connectivity for epoch 270
#     computing connectivity for epoch 271
#     computing connectivity for epoch 272
#     computing connectivity for epoch 273
#     computing connectivity for epoch 274
#     computing connectivity for epoch 275
#     computing connectivity for epoch 276
#     computing connectivity for epoch 277
#     computing connectivity for epoch 278
#     computing connectivity for epoch 279
#     computing connectivity for epoch 280
#     computing connectivity for epoch 281
#     computing connectivity for epoch 282
#     computing connectivity for epoch 283
#     computing connectivity for epoch 284
#     computing connectivity for epoch 285
#     computing connectivity for epoch 286
#     computing connectivity for epoch 287
#     computing connectivity for epoch 288
#     computing connectivity for epoch 289
#     computing connectivity for epoch 290
#     computing connectivity for epoch 291
#     computing connectivity for epoch 292
#     computing connectivity for epoch 293
#     computing connectivity for epoch 294
#     computing connectivity for epoch 295
#     computing connectivity for epoch 296
#     computing connectivity for epoch 297
#     computing connectivity for epoch 298
#     computing connectivity for epoch 299
#     computing connectivity for epoch 300
#     computing connectivity for epoch 301
#     computing connectivity for epoch 302
#     computing connectivity for epoch 303
#     computing connectivity for epoch 304
#     computing connectivity for epoch 305
#     computing connectivity for epoch 306
#     computing connectivity for epoch 307
#     computing connectivity for epoch 308
#     computing connectivity for epoch 309
#     computing connectivity for epoch 310
#     computing connectivity for epoch 311
#     computing connectivity for epoch 312
#     computing connectivity for epoch 313
#     computing connectivity for epoch 314
#     computing connectivity for epoch 315
#     computing connectivity for epoch 316
#     computing connectivity for epoch 317
#     computing connectivity for epoch 318
#     computing connectivity for epoch 319
#     computing connectivity for epoch 320
#     computing connectivity for epoch 321
#     computing connectivity for epoch 322
#     computing connectivity for epoch 323
#     computing connectivity for epoch 324
#     computing connectivity for epoch 325
#     computing connectivity for epoch 326
#     computing connectivity for epoch 327
#     computing connectivity for epoch 328
#     computing connectivity for epoch 329
#     computing connectivity for epoch 330
#     computing connectivity for epoch 331
#     computing connectivity for epoch 332
#     computing connectivity for epoch 333
#     computing connectivity for epoch 334
#     computing connectivity for epoch 335
#     computing connectivity for epoch 336
#     computing connectivity for epoch 337
#     computing connectivity for epoch 338
#     computing connectivity for epoch 339
#     computing connectivity for epoch 340
#     computing connectivity for epoch 341
#     computing connectivity for epoch 342
#     computing connectivity for epoch 343
#     computing connectivity for epoch 344
#     computing connectivity for epoch 345
#     computing connectivity for epoch 346
#     computing connectivity for epoch 347
#     computing connectivity for epoch 348
#     computing connectivity for epoch 349
#     computing connectivity for epoch 350
#     computing connectivity for epoch 351
#     computing connectivity for epoch 352
#     computing connectivity for epoch 353
#     computing connectivity for epoch 354
#     computing connectivity for epoch 355
#     computing connectivity for epoch 356
#     computing connectivity for epoch 357
#     computing connectivity for epoch 358
#     computing connectivity for epoch 359
#     computing connectivity for epoch 360
#     computing connectivity for epoch 361
#     computing connectivity for epoch 362
#     computing connectivity for epoch 363
#     computing connectivity for epoch 364
#     computing connectivity for epoch 365
#     computing connectivity for epoch 366
#     computing connectivity for epoch 367
#     computing connectivity for epoch 368
#     computing connectivity for epoch 369
#     computing connectivity for epoch 370
#     computing connectivity for epoch 371
#     computing connectivity for epoch 372
#     computing connectivity for epoch 373
#     computing connectivity for epoch 374
#     computing connectivity for epoch 375
#     computing connectivity for epoch 376
#     computing connectivity for epoch 377
#     computing connectivity for epoch 378
#     computing connectivity for epoch 379
#     computing connectivity for epoch 380
#     computing connectivity for epoch 381
#     computing connectivity for epoch 382
#     computing connectivity for epoch 383
#     computing connectivity for epoch 384
#     computing connectivity for epoch 385
#     computing connectivity for epoch 386
#     computing connectivity for epoch 387
#     computing connectivity for epoch 388
#     computing connectivity for epoch 389
#     computing connectivity for epoch 390
#     computing connectivity for epoch 391
#     computing connectivity for epoch 392
#     computing connectivity for epoch 393
#     computing connectivity for epoch 394
#     computing connectivity for epoch 395
#     computing connectivity for epoch 396
#     computing connectivity for epoch 397
#     computing connectivity for epoch 398
#     computing connectivity for epoch 399
#     computing connectivity for epoch 400
#     computing connectivity for epoch 401
#     computing connectivity for epoch 402
#     computing connectivity for epoch 403
#     computing connectivity for epoch 404
#     computing connectivity for epoch 405
#     computing connectivity for epoch 406
#     computing connectivity for epoch 407
#     computing connectivity for epoch 408
#     computing connectivity for epoch 409
#     computing connectivity for epoch 410
#     computing connectivity for epoch 411
#     computing connectivity for epoch 412
#     computing connectivity for epoch 413
#     computing connectivity for epoch 414
#     computing connectivity for epoch 415
#     computing connectivity for epoch 416
#     computing connectivity for epoch 417
#     computing connectivity for epoch 418
#     computing connectivity for epoch 419
#     computing connectivity for epoch 420
#     computing connectivity for epoch 421
#     computing connectivity for epoch 422
#     computing connectivity for epoch 423
#     computing connectivity for epoch 424
#     computing connectivity for epoch 425
#     computing connectivity for epoch 426
#     computing connectivity for epoch 427
#     computing connectivity for epoch 428
#     computing connectivity for epoch 429
#     computing connectivity for epoch 430
#     computing connectivity for epoch 431
#     computing connectivity for epoch 432
#     computing connectivity for epoch 433
#     computing connectivity for epoch 434
#     computing connectivity for epoch 435
#     computing connectivity for epoch 436
#     computing connectivity for epoch 437
#     computing connectivity for epoch 438
#     computing connectivity for epoch 439
#     computing connectivity for epoch 440
#     computing connectivity for epoch 441
#     computing connectivity for epoch 442
#     computing connectivity for epoch 443
#     computing connectivity for epoch 444
#     computing connectivity for epoch 445
#     computing connectivity for epoch 446
#     computing connectivity for epoch 447
#     computing connectivity for epoch 448
#     computing connectivity for epoch 449
#     computing connectivity for epoch 450
#     computing connectivity for epoch 451
#     computing connectivity for epoch 452
#     computing connectivity for epoch 453
#     computing connectivity for epoch 454
#     computing connectivity for epoch 455
#     computing connectivity for epoch 456
#     computing connectivity for epoch 457
#     computing connectivity for epoch 458
#     computing connectivity for epoch 459
#     computing connectivity for epoch 460
#     computing connectivity for epoch 461
#     computing connectivity for epoch 462
#     computing connectivity for epoch 463
#     computing connectivity for epoch 464
#     computing connectivity for epoch 465
#     computing connectivity for epoch 466
#     computing connectivity for epoch 467
#     computing connectivity for epoch 468
#     computing connectivity for epoch 469
#     computing connectivity for epoch 470
#     computing connectivity for epoch 471
#     computing connectivity for epoch 472
#     computing connectivity for epoch 473
#     computing connectivity for epoch 474
#     computing connectivity for epoch 475
#     computing connectivity for epoch 476
#     computing connectivity for epoch 477
#     computing connectivity for epoch 478
#     computing connectivity for epoch 479
#     computing connectivity for epoch 480
#     computing connectivity for epoch 481
#     computing connectivity for epoch 482
#     computing connectivity for epoch 483
#     computing connectivity for epoch 484
#     computing connectivity for epoch 485
#     computing connectivity for epoch 486
#     computing connectivity for epoch 487
#     computing connectivity for epoch 488
#     computing connectivity for epoch 489
#     computing connectivity for epoch 490
#     computing connectivity for epoch 491
#     computing connectivity for epoch 492
#     computing connectivity for epoch 493
#     computing connectivity for epoch 494
#     computing connectivity for epoch 495
#     computing connectivity for epoch 496
#     computing connectivity for epoch 497
#     computing connectivity for epoch 498
#     computing connectivity for epoch 499
#     computing connectivity for epoch 500
#     computing connectivity for epoch 501
#     computing connectivity for epoch 502
#     computing connectivity for epoch 503
#     computing connectivity for epoch 504
#     computing connectivity for epoch 505
#     computing connectivity for epoch 506
#     computing connectivity for epoch 507
#     computing connectivity for epoch 508
#     computing connectivity for epoch 509
#     computing connectivity for epoch 510
#     computing connectivity for epoch 511
#     computing connectivity for epoch 512
#     computing connectivity for epoch 513
#     computing connectivity for epoch 514
#     computing connectivity for epoch 515
#     computing connectivity for epoch 516
#     computing connectivity for epoch 517
#     computing connectivity for epoch 518
#     computing connectivity for epoch 519
#     computing connectivity for epoch 520
#     computing connectivity for epoch 521
#     computing connectivity for epoch 522
#     computing connectivity for epoch 523
#     computing connectivity for epoch 524
#     computing connectivity for epoch 525
#     computing connectivity for epoch 526
#     computing connectivity for epoch 527
#     computing connectivity for epoch 528
#     computing connectivity for epoch 529
#     computing connectivity for epoch 530
#     computing connectivity for epoch 531
#     computing connectivity for epoch 532
#     computing connectivity for epoch 533
#     computing connectivity for epoch 534
#     computing connectivity for epoch 535
#     computing connectivity for epoch 536
#     computing connectivity for epoch 537
#     computing connectivity for epoch 538
#     computing connectivity for epoch 539
#     computing connectivity for epoch 540
#     computing connectivity for epoch 541
#     computing connectivity for epoch 542
#     computing connectivity for epoch 543
#     computing connectivity for epoch 544
#     computing connectivity for epoch 545
#     computing connectivity for epoch 546
#     computing connectivity for epoch 547
#     computing connectivity for epoch 548
#     computing connectivity for epoch 549
#     computing connectivity for epoch 550
#     computing connectivity for epoch 551
#     computing connectivity for epoch 552
#     computing connectivity for epoch 553
#     computing connectivity for epoch 554
#     computing connectivity for epoch 555
#     computing connectivity for epoch 556
#     computing connectivity for epoch 557
#     computing connectivity for epoch 558
#     computing connectivity for epoch 559
#     computing connectivity for epoch 560
#     computing connectivity for epoch 561
#     computing connectivity for epoch 562
#     computing connectivity for epoch 563
#     computing connectivity for epoch 564
#     computing connectivity for epoch 565
#     computing connectivity for epoch 566
#     computing connectivity for epoch 567
#     computing connectivity for epoch 568
#     computing connectivity for epoch 569
#     computing connectivity for epoch 570
#     computing connectivity for epoch 571
#     computing connectivity for epoch 572
#     computing connectivity for epoch 573
#     computing connectivity for epoch 574
#     computing connectivity for epoch 575
#     computing connectivity for epoch 576
#     computing connectivity for epoch 577
#     computing connectivity for epoch 578
#     computing connectivity for epoch 579
#     computing connectivity for epoch 580
#     computing connectivity for epoch 581
#     computing connectivity for epoch 582
#     computing connectivity for epoch 583
#     computing connectivity for epoch 584
#     computing connectivity for epoch 585
#     computing connectivity for epoch 586
#     computing connectivity for epoch 587
#     computing connectivity for epoch 588
#     computing connectivity for epoch 589
#     computing connectivity for epoch 590
#     computing connectivity for epoch 591
#     computing connectivity for epoch 592
#     computing connectivity for epoch 593
#     computing connectivity for epoch 594
#     computing connectivity for epoch 595
#     computing connectivity for epoch 596
#     computing connectivity for epoch 597
#     computing connectivity for epoch 598
#     computing connectivity for epoch 599
#     computing connectivity for epoch 600
#     computing connectivity for epoch 601
#     computing connectivity for epoch 602
#     computing connectivity for epoch 603
#     computing connectivity for epoch 604
#     computing connectivity for epoch 605
#     computing connectivity for epoch 606
#     computing connectivity for epoch 607
#     computing connectivity for epoch 608
#     computing connectivity for epoch 609
#     computing connectivity for epoch 610
#     computing connectivity for epoch 611
#     computing connectivity for epoch 612
#     computing connectivity for epoch 613
#     computing connectivity for epoch 614
#     computing connectivity for epoch 615
#     computing connectivity for epoch 616
#     computing connectivity for epoch 617
#     computing connectivity for epoch 618
#     computing connectivity for epoch 619
#     computing connectivity for epoch 620
#     computing connectivity for epoch 621
#     computing connectivity for epoch 622
#     computing connectivity for epoch 623
#     computing connectivity for epoch 624
#     computing connectivity for epoch 625
#     computing connectivity for epoch 626
#     computing connectivity for epoch 627
#     computing connectivity for epoch 628
#     computing connectivity for epoch 629
#     computing connectivity for epoch 630
#     computing connectivity for epoch 631
#     computing connectivity for epoch 632
#     computing connectivity for epoch 633
#     computing connectivity for epoch 634
#     computing connectivity for epoch 635
#     computing connectivity for epoch 636
#     computing connectivity for epoch 637
#     computing connectivity for epoch 638
#     computing connectivity for epoch 639
#     computing connectivity for epoch 640
#     computing connectivity for epoch 641
#     computing connectivity for epoch 642
#     computing connectivity for epoch 643
#     computing connectivity for epoch 644
#     computing connectivity for epoch 645
#     computing connectivity for epoch 646
#     computing connectivity for epoch 647
#     computing connectivity for epoch 648
#     computing connectivity for epoch 649
#     computing connectivity for epoch 650
#     computing connectivity for epoch 651
#     computing connectivity for epoch 652
#     computing connectivity for epoch 653
#     computing connectivity for epoch 654
#     computing connectivity for epoch 655
#     computing connectivity for epoch 656
#     computing connectivity for epoch 657
#     computing connectivity for epoch 658
#     computing connectivity for epoch 659
#     computing connectivity for epoch 660
#     computing connectivity for epoch 661
#     computing connectivity for epoch 662
#     computing connectivity for epoch 663
#     computing connectivity for epoch 664
#     computing connectivity for epoch 665
#     computing connectivity for epoch 666
#     computing connectivity for epoch 667
#     computing connectivity for epoch 668
#     computing connectivity for epoch 669
#     computing connectivity for epoch 670
#     computing connectivity for epoch 671
#     computing connectivity for epoch 672
#     computing connectivity for epoch 673
#     computing connectivity for epoch 674
#     computing connectivity for epoch 675
#     computing connectivity for epoch 676
#     computing connectivity for epoch 677
#     computing connectivity for epoch 678
#     computing connectivity for epoch 679
#     computing connectivity for epoch 680
#     computing connectivity for epoch 681
#     computing connectivity for epoch 682
#     computing connectivity for epoch 683
#     computing connectivity for epoch 684
#     computing connectivity for epoch 685
#     computing connectivity for epoch 686
#     computing connectivity for epoch 687
#     computing connectivity for epoch 688
#     computing connectivity for epoch 689
#     computing connectivity for epoch 690
#     computing connectivity for epoch 691
#     computing connectivity for epoch 692
#     computing connectivity for epoch 693
#     computing connectivity for epoch 694
#     computing connectivity for epoch 695
#     computing connectivity for epoch 696
#     computing connectivity for epoch 697
#     computing connectivity for epoch 698
#     computing connectivity for epoch 699
#     computing connectivity for epoch 700
#     computing connectivity for epoch 701
#     computing connectivity for epoch 702
#     computing connectivity for epoch 703
#     computing connectivity for epoch 704
#     computing connectivity for epoch 705
#     computing connectivity for epoch 706
#     computing connectivity for epoch 707
#     computing connectivity for epoch 708
#     computing connectivity for epoch 709
#     computing connectivity for epoch 710
#     computing connectivity for epoch 711
#     computing connectivity for epoch 712
#     computing connectivity for epoch 713
#     computing connectivity for epoch 714
#     computing connectivity for epoch 715
#     computing connectivity for epoch 716
#     computing connectivity for epoch 717
#     computing connectivity for epoch 718
#     computing connectivity for epoch 719
#     computing connectivity for epoch 720
#     computing connectivity for epoch 721
#     computing connectivity for epoch 722
#     computing connectivity for epoch 723
#     computing connectivity for epoch 724
#     computing connectivity for epoch 725
#     computing connectivity for epoch 726
#     computing connectivity for epoch 727
#     computing connectivity for epoch 728
#     computing connectivity for epoch 729
#     computing connectivity for epoch 730
#     computing connectivity for epoch 731
#     computing connectivity for epoch 732
#     computing connectivity for epoch 733
#     computing connectivity for epoch 734
#     computing connectivity for epoch 735
#     computing connectivity for epoch 736
#     computing connectivity for epoch 737
#     computing connectivity for epoch 738
#     computing connectivity for epoch 739
#     computing connectivity for epoch 740
#     computing connectivity for epoch 741
#     computing connectivity for epoch 742
#     computing connectivity for epoch 743
#     computing connectivity for epoch 744
#     computing connectivity for epoch 745
#     computing connectivity for epoch 746
#     computing connectivity for epoch 747
#     computing connectivity for epoch 748
#     computing connectivity for epoch 749
#     computing connectivity for epoch 750
#     computing connectivity for epoch 751
#     computing connectivity for epoch 752
#     computing connectivity for epoch 753
#     computing connectivity for epoch 754
#     computing connectivity for epoch 755
#     computing connectivity for epoch 756
#     computing connectivity for epoch 757
#     computing connectivity for epoch 758
#     computing connectivity for epoch 759
#     computing connectivity for epoch 760
#     computing connectivity for epoch 761
#     computing connectivity for epoch 762
#     computing connectivity for epoch 763
#     computing connectivity for epoch 764
#     computing connectivity for epoch 765
#     computing connectivity for epoch 766
#     computing connectivity for epoch 767
#     computing connectivity for epoch 768
#     computing connectivity for epoch 769
#     computing connectivity for epoch 770
#     computing connectivity for epoch 771
#     computing connectivity for epoch 772
#     computing connectivity for epoch 773
#     computing connectivity for epoch 774
#     computing connectivity for epoch 775
#     computing connectivity for epoch 776
#     computing connectivity for epoch 777
#     computing connectivity for epoch 778
#     computing connectivity for epoch 779
#     computing connectivity for epoch 780
#     computing connectivity for epoch 781
#     computing connectivity for epoch 782
#     computing connectivity for epoch 783
#     computing connectivity for epoch 784
#     computing connectivity for epoch 785
#     computing connectivity for epoch 786
#     computing connectivity for epoch 787
#     computing connectivity for epoch 788
#     computing connectivity for epoch 789
#     computing connectivity for epoch 790
#     computing connectivity for epoch 791
#     computing connectivity for epoch 792
#     computing connectivity for epoch 793
#     computing connectivity for epoch 794
#     computing connectivity for epoch 795
#     computing connectivity for epoch 796
#     computing connectivity for epoch 797
#     computing connectivity for epoch 798
#     computing connectivity for epoch 799
#     computing connectivity for epoch 800
#     computing connectivity for epoch 801
#     computing connectivity for epoch 802
#     computing connectivity for epoch 803
#     computing connectivity for epoch 804
#     computing connectivity for epoch 805
#     computing connectivity for epoch 806
#     computing connectivity for epoch 807
#     computing connectivity for epoch 808
#     computing connectivity for epoch 809
#     computing connectivity for epoch 810
#     computing connectivity for epoch 811
#     computing connectivity for epoch 812
#     computing connectivity for epoch 813
#     computing connectivity for epoch 814
#     computing connectivity for epoch 815
#     computing connectivity for epoch 816
#     computing connectivity for epoch 817
#     computing connectivity for epoch 818
#     computing connectivity for epoch 819
#     computing connectivity for epoch 820
#     computing connectivity for epoch 821
#     computing connectivity for epoch 822
#     computing connectivity for epoch 823
#     computing connectivity for epoch 824
#     computing connectivity for epoch 825
#     computing connectivity for epoch 826
#     computing connectivity for epoch 827
#     computing connectivity for epoch 828
#     computing connectivity for epoch 829
#     computing connectivity for epoch 830
#     computing connectivity for epoch 831
#     computing connectivity for epoch 832
#     computing connectivity for epoch 833
#     computing connectivity for epoch 834
#     computing connectivity for epoch 835
#     computing connectivity for epoch 836
#     computing connectivity for epoch 837
#     computing connectivity for epoch 838
#     computing connectivity for epoch 839
#     computing connectivity for epoch 840
#     computing connectivity for epoch 841
#     computing connectivity for epoch 842
#     computing connectivity for epoch 843
#     computing connectivity for epoch 844
#     computing connectivity for epoch 845
#     computing connectivity for epoch 846
#     computing connectivity for epoch 847
#     computing connectivity for epoch 848
#     computing connectivity for epoch 849
#     computing connectivity for epoch 850
#     computing connectivity for epoch 851
#     computing connectivity for epoch 852
#     computing connectivity for epoch 853
#     computing connectivity for epoch 854
#     computing connectivity for epoch 855
#     computing connectivity for epoch 856
#     computing connectivity for epoch 857
#     computing connectivity for epoch 858
#     computing connectivity for epoch 859
#     computing connectivity for epoch 860
#     computing connectivity for epoch 861
#     computing connectivity for epoch 862
#     computing connectivity for epoch 863
#     computing connectivity for epoch 864
#     computing connectivity for epoch 865
#     computing connectivity for epoch 866
#     computing connectivity for epoch 867
#     computing connectivity for epoch 868
#     computing connectivity for epoch 869
#     computing connectivity for epoch 870
#     computing connectivity for epoch 871
#     computing connectivity for epoch 872
#     computing connectivity for epoch 873
#     computing connectivity for epoch 874
#     computing connectivity for epoch 875
#     computing connectivity for epoch 876
#     computing connectivity for epoch 877
#     computing connectivity for epoch 878
#     computing connectivity for epoch 879
#     computing connectivity for epoch 880
#     computing connectivity for epoch 881
#     computing connectivity for epoch 882
#     computing connectivity for epoch 883
#     computing connectivity for epoch 884
#     computing connectivity for epoch 885
#     computing connectivity for epoch 886
#     computing connectivity for epoch 887
#     computing connectivity for epoch 888
#     computing connectivity for epoch 889
#     computing connectivity for epoch 890
#     computing connectivity for epoch 891
#     computing connectivity for epoch 892
#     computing connectivity for epoch 893
#     computing connectivity for epoch 894
#     computing connectivity for epoch 895
#     computing connectivity for epoch 896
#     computing connectivity for epoch 897
#     computing connectivity for epoch 898
#     computing connectivity for epoch 899
#     computing connectivity for epoch 900
#     computing connectivity for epoch 901
#     computing connectivity for epoch 902
#     computing connectivity for epoch 903
#     computing connectivity for epoch 904
#     computing connectivity for epoch 905
#     computing connectivity for epoch 906
#     computing connectivity for epoch 907
#     computing connectivity for epoch 908
#     computing connectivity for epoch 909
#     computing connectivity for epoch 910
#     computing connectivity for epoch 911
#     computing connectivity for epoch 912
#     computing connectivity for epoch 913
#     computing connectivity for epoch 914
#     computing connectivity for epoch 915
#     computing connectivity for epoch 916
#     computing connectivity for epoch 917
#     computing connectivity for epoch 918
#     computing connectivity for epoch 919
#     computing connectivity for epoch 920
#     computing connectivity for epoch 921
#     computing connectivity for epoch 922
#     computing connectivity for epoch 923
#     computing connectivity for epoch 924
#     computing connectivity for epoch 925
#     computing connectivity for epoch 926
#     computing connectivity for epoch 927
#     computing connectivity for epoch 928
#     computing connectivity for epoch 929
#     computing connectivity for epoch 930
#     computing connectivity for epoch 931
#     computing connectivity for epoch 932
#     computing connectivity for epoch 933
#     computing connectivity for epoch 934
#     computing connectivity for epoch 935
#     computing connectivity for epoch 936
#     computing connectivity for epoch 937
#     computing connectivity for epoch 938
#     computing connectivity for epoch 939
#     computing connectivity for epoch 940
#     computing connectivity for epoch 941
#     computing connectivity for epoch 942
#     computing connectivity for epoch 943
#     computing connectivity for epoch 944
#     computing connectivity for epoch 945
#     computing connectivity for epoch 946
#     computing connectivity for epoch 947
#     computing connectivity for epoch 948
#     computing connectivity for epoch 949
#     computing connectivity for epoch 950
#     computing connectivity for epoch 951
#     computing connectivity for epoch 952
#     computing connectivity for epoch 953
#     computing connectivity for epoch 954
#     computing connectivity for epoch 955
#     computing connectivity for epoch 956
#     computing connectivity for epoch 957
#     computing connectivity for epoch 958
#     computing connectivity for epoch 959
#     computing connectivity for epoch 960
#     computing connectivity for epoch 961
#     computing connectivity for epoch 962
#     computing connectivity for epoch 963
#     computing connectivity for epoch 964
#     computing connectivity for epoch 965
#     computing connectivity for epoch 966
#     computing connectivity for epoch 967
#     computing connectivity for epoch 968
#     computing connectivity for epoch 969
#     computing connectivity for epoch 970
#     computing connectivity for epoch 971
#     computing connectivity for epoch 972
#     computing connectivity for epoch 973
#     computing connectivity for epoch 974
#     computing connectivity for epoch 975
#     computing connectivity for epoch 976
#     computing connectivity for epoch 977
#     computing connectivity for epoch 978
#     computing connectivity for epoch 979
#     computing connectivity for epoch 980
#     computing connectivity for epoch 981
#     computing connectivity for epoch 982
#     computing connectivity for epoch 983
#     computing connectivity for epoch 984
#     computing connectivity for epoch 985
#     computing connectivity for epoch 986
#     computing connectivity for epoch 987
#     computing connectivity for epoch 988
#     computing connectivity for epoch 989
#     computing connectivity for epoch 990
#     computing connectivity for epoch 991
#     computing connectivity for epoch 992
#     computing connectivity for epoch 993
#     computing connectivity for epoch 994
#     computing connectivity for epoch 995
#     computing connectivity for epoch 996
#     computing connectivity for epoch 997
#     computing connectivity for epoch 998
#     computing connectivity for epoch 999
#     computing connectivity for epoch 1000
#     computing connectivity for epoch 1001
#     computing connectivity for epoch 1002
#     computing connectivity for epoch 1003
#     computing connectivity for epoch 1004
#     computing connectivity for epoch 1005
#     computing connectivity for epoch 1006
#     computing connectivity for epoch 1007
#     computing connectivity for epoch 1008
#     computing connectivity for epoch 1009
#     computing connectivity for epoch 1010
#     computing connectivity for epoch 1011
#     computing connectivity for epoch 1012
#     computing connectivity for epoch 1013
#     computing connectivity for epoch 1014
#     computing connectivity for epoch 1015
#     computing connectivity for epoch 1016
#     computing connectivity for epoch 1017
#     computing connectivity for epoch 1018
#     computing connectivity for epoch 1019
#     computing connectivity for epoch 1020
#     computing connectivity for epoch 1021
#     computing connectivity for epoch 1022
#     computing connectivity for epoch 1023
#     computing connectivity for epoch 1024
#     computing connectivity for epoch 1025
#     computing connectivity for epoch 1026
#     computing connectivity for epoch 1027
#     computing connectivity for epoch 1028
#     computing connectivity for epoch 1029
#     computing connectivity for epoch 1030
#     computing connectivity for epoch 1031
#     computing connectivity for epoch 1032
#     computing connectivity for epoch 1033
#     computing connectivity for epoch 1034
#     computing connectivity for epoch 1035
#     computing connectivity for epoch 1036
#     computing connectivity for epoch 1037
#     computing connectivity for epoch 1038
#     computing connectivity for epoch 1039
#     computing connectivity for epoch 1040
#     computing connectivity for epoch 1041
#     computing connectivity for epoch 1042
#     computing connectivity for epoch 1043
#     computing connectivity for epoch 1044
#     computing connectivity for epoch 1045
#     computing connectivity for epoch 1046
#     computing connectivity for epoch 1047
#     computing connectivity for epoch 1048
#     computing connectivity for epoch 1049
#     computing connectivity for epoch 1050
#     computing connectivity for epoch 1051
#     computing connectivity for epoch 1052
#     computing connectivity for epoch 1053
#     computing connectivity for epoch 1054
#     computing connectivity for epoch 1055
#     computing connectivity for epoch 1056
#     computing connectivity for epoch 1057
#     computing connectivity for epoch 1058
#     computing connectivity for epoch 1059
#     computing connectivity for epoch 1060
#     computing connectivity for epoch 1061
#     computing connectivity for epoch 1062
#     computing connectivity for epoch 1063
#     computing connectivity for epoch 1064
#     computing connectivity for epoch 1065
#     computing connectivity for epoch 1066
#     computing connectivity for epoch 1067
#     computing connectivity for epoch 1068
#     computing connectivity for epoch 1069
#     computing connectivity for epoch 1070
#     computing connectivity for epoch 1071
#     computing connectivity for epoch 1072
#     computing connectivity for epoch 1073
#     computing connectivity for epoch 1074
#     computing connectivity for epoch 1075
#     computing connectivity for epoch 1076
#     computing connectivity for epoch 1077
#     computing connectivity for epoch 1078
#     computing connectivity for epoch 1079
#     computing connectivity for epoch 1080
#     computing connectivity for epoch 1081
#     computing connectivity for epoch 1082
#     computing connectivity for epoch 1083
#     computing connectivity for epoch 1084
#     computing connectivity for epoch 1085
#     computing connectivity for epoch 1086
#     computing connectivity for epoch 1087
#     computing connectivity for epoch 1088
#     computing connectivity for epoch 1089
#     computing connectivity for epoch 1090
#     computing connectivity for epoch 1091
#     computing connectivity for epoch 1092
#     computing connectivity for epoch 1093
#     computing connectivity for epoch 1094
#     computing connectivity for epoch 1095
#     computing connectivity for epoch 1096
#     computing connectivity for epoch 1097
#     computing connectivity for epoch 1098
#     computing connectivity for epoch 1099
#     computing connectivity for epoch 1100
#     computing connectivity for epoch 1101
#     computing connectivity for epoch 1102
#     computing connectivity for epoch 1103
#     computing connectivity for epoch 1104
#     computing connectivity for epoch 1105
#     computing connectivity for epoch 1106
#     computing connectivity for epoch 1107
#     computing connectivity for epoch 1108
#     computing connectivity for epoch 1109
#     computing connectivity for epoch 1110
#     computing connectivity for epoch 1111
#     computing connectivity for epoch 1112
#     computing connectivity for epoch 1113
#     computing connectivity for epoch 1114
#     computing connectivity for epoch 1115
#     computing connectivity for epoch 1116
#     computing connectivity for epoch 1117
#     computing connectivity for epoch 1118
#     computing connectivity for epoch 1119
#     computing connectivity for epoch 1120
#     computing connectivity for epoch 1121
#     computing connectivity for epoch 1122
#     computing connectivity for epoch 1123
#     computing connectivity for epoch 1124
#     computing connectivity for epoch 1125
#     computing connectivity for epoch 1126
#     computing connectivity for epoch 1127
#     computing connectivity for epoch 1128
#     computing connectivity for epoch 1129
#     computing connectivity for epoch 1130
#     computing connectivity for epoch 1131
#     computing connectivity for epoch 1132
#     computing connectivity for epoch 1133
#     computing connectivity for epoch 1134
#     computing connectivity for epoch 1135
#     computing connectivity for epoch 1136
#     computing connectivity for epoch 1137
#     computing connectivity for epoch 1138
#     computing connectivity for epoch 1139
#     computing connectivity for epoch 1140
#     computing connectivity for epoch 1141
#     computing connectivity for epoch 1142
#     computing connectivity for epoch 1143
#     computing connectivity for epoch 1144
#     computing connectivity for epoch 1145
#     computing connectivity for epoch 1146
#     computing connectivity for epoch 1147
#     computing connectivity for epoch 1148
#     computing connectivity for epoch 1149
#     computing connectivity for epoch 1150
#     computing connectivity for epoch 1151
#     computing connectivity for epoch 1152
#     computing connectivity for epoch 1153
#     computing connectivity for epoch 1154
#     computing connectivity for epoch 1155
# ...
#     computing connectivity for epoch 1553
#     computing connectivity for epoch 1554
#     computing connectivity for epoch 1555
#     computing connectivity for epoch 1556
#     computing connectivity for epoch 1557
#     computing connectivity for epoch 1558
#     computing connectivity for epoch 1559
#     computing connectivity for epoch 1560
#     computing connectivity for epoch 1561
#     computing connectivity for epoch 1562
#     computing connectivity for epoch 1563
#     computing connectivity for epoch 1564
#     computing connectivity for epoch 1565
#     computing connectivity for epoch 1566
#     computing connectivity for epoch 1567
#     computing connectivity for epoch 1568
#     computing connectivity for epoch 1569
#     computing connectivity for epoch 1570
#     computing connectivity for epoch 1571
#     computing connectivity for epoch 1572
#     computing connectivity for epoch 1573
#     computing connectivity for epoch 1574
#     computing connectivity for epoch 1575
#     computing connectivity for epoch 1576
#     computing connectivity for epoch 1577
#     computing connectivity for epoch 1578
#     computing connectivity for epoch 1579
#     computing connectivity for epoch 1580
#     computing connectivity for epoch 1581
#     computing connectivity for epoch 1582
#     computing connectivity for epoch 1583
#     computing connectivity for epoch 1584
#     computing connectivity for epoch 1585
#     computing connectivity for epoch 1586
#     computing connectivity for epoch 1587
#     computing connectivity for epoch 1588
#     computing connectivity for epoch 1589
#     computing connectivity for epoch 1590
#     computing connectivity for epoch 1591
#     computing connectivity for epoch 1592
#     computing connectivity for epoch 1593
#     computing connectivity for epoch 1594
#     computing connectivity for epoch 1595
#     computing connectivity for epoch 1596
#     computing connectivity for epoch 1597
#     computing connectivity for epoch 1598
#     computing connectivity for epoch 1599
#     computing connectivity for epoch 1600
#     computing connectivity for epoch 1601
#     computing connectivity for epoch 1602
#     computing connectivity for epoch 1603
#     computing connectivity for epoch 1604
#     computing connectivity for epoch 1605
#     computing connectivity for epoch 1606
#     computing connectivity for epoch 1607
#     computing connectivity for epoch 1608
#     computing connectivity for epoch 1609
#     computing connectivity for epoch 1610
#     computing connectivity for epoch 1611
#     computing connectivity for epoch 1612
#     computing connectivity for epoch 1613
#     computing connectivity for epoch 1614
#     computing connectivity for epoch 1615
#     computing connectivity for epoch 1616
#     computing connectivity for epoch 1617
#     computing connectivity for epoch 1618
#     computing connectivity for epoch 1619
#     computing connectivity for epoch 1620
#     computing connectivity for epoch 1621
#     computing connectivity for epoch 1622
#     computing connectivity for epoch 1623
#     computing connectivity for epoch 1624
#     computing connectivity for epoch 1625
#     computing connectivity for epoch 1626
#     computing connectivity for epoch 1627
#     computing connectivity for epoch 1628
#     computing connectivity for epoch 1629
#     computing connectivity for epoch 1630
#     computing connectivity for epoch 1631
#     computing connectivity for epoch 1632
#     computing connectivity for epoch 1633
#     computing connectivity for epoch 1634
#     computing connectivity for epoch 1635
#     computing connectivity for epoch 1636
#     computing connectivity for epoch 1637
#     computing connectivity for epoch 1638
#     computing connectivity for epoch 1639
#     computing connectivity for epoch 1640
#     computing connectivity for epoch 1641
#     computing connectivity for epoch 1642
#     computing connectivity for epoch 1643
#     computing connectivity for epoch 1644
#     computing connectivity for epoch 1645
#     computing connectivity for epoch 1646
#     computing connectivity for epoch 1647
#     computing connectivity for epoch 1648
#     computing connectivity for epoch 1649
#     computing connectivity for epoch 1650
#     computing connectivity for epoch 1651
#     computing connectivity for epoch 1652
#     computing connectivity for epoch 1653
#     computing connectivity for epoch 1654
#     computing connectivity for epoch 1655
#     computing connectivity for epoch 1656
#     computing connectivity for epoch 1657
#     computing connectivity for epoch 1658
#     computing connectivity for epoch 1659
#     computing connectivity for epoch 1660
#     computing connectivity for epoch 1661
#     computing connectivity for epoch 1662
#     computing connectivity for epoch 1663
#     computing connectivity for epoch 1664
#     computing connectivity for epoch 1665
#     computing connectivity for epoch 1666
#     computing connectivity for epoch 1667
#     computing connectivity for epoch 1668
#     computing connectivity for epoch 1669
#     computing connectivity for epoch 1670
#     computing connectivity for epoch 1671
#     computing connectivity for epoch 1672
#     computing connectivity for epoch 1673
#     computing connectivity for epoch 1674
#     computing connectivity for epoch 1675
#     computing connectivity for epoch 1676
#     computing connectivity for epoch 1677
#     computing connectivity for epoch 1678
#     computing connectivity for epoch 1679
#     computing connectivity for epoch 1680
#     computing connectivity for epoch 1681
#     computing connectivity for epoch 1682
#     computing connectivity for epoch 1683
#     computing connectivity for epoch 1684
#     computing connectivity for epoch 1685
#     computing connectivity for epoch 1686
#     computing connectivity for epoch 1687
#     computing connectivity for epoch 1688
#     computing connectivity for epoch 1689
#     computing connectivity for epoch 1690
#     computing connectivity for epoch 1691
#     computing connectivity for epoch 1692
#     computing connectivity for epoch 1693
#     computing connectivity for epoch 1694
#     computing connectivity for epoch 1695
#     computing connectivity for epoch 1696
#     computing connectivity for epoch 1697
#     computing connectivity for epoch 1698
#     computing connectivity for epoch 1699
#     computing connectivity for epoch 1700
#     computing connectivity for epoch 1701
#     computing connectivity for epoch 1702
#     computing connectivity for epoch 1703
#     computing connectivity for epoch 1704
#     computing connectivity for epoch 1705
#     computing connectivity for epoch 1706
#     computing connectivity for epoch 1707
#     computing connectivity for epoch 1708
#     computing connectivity for epoch 1709
#     computing connectivity for epoch 1710
#     computing connectivity for epoch 1711
#     computing connectivity for epoch 1712
#     computing connectivity for epoch 1713
#     computing connectivity for epoch 1714
#     computing connectivity for epoch 1715
#     computing connectivity for epoch 1716
#     computing connectivity for epoch 1717
#     computing connectivity for epoch 1718
#     computing connectivity for epoch 1719
#     computing connectivity for epoch 1720
#     computing connectivity for epoch 1721
#     computing connectivity for epoch 1722
#     computing connectivity for epoch 1723
#     computing connectivity for epoch 1724
#     computing connectivity for epoch 1725
#     computing connectivity for epoch 1726
#     computing connectivity for epoch 1727
#     computing connectivity for epoch 1728
#     computing connectivity for epoch 1729
#     computing connectivity for epoch 1730
#     computing connectivity for epoch 1731
#     computing connectivity for epoch 1732
#     computing connectivity for epoch 1733
#     computing connectivity for epoch 1734
#     computing connectivity for epoch 1735
#     computing connectivity for epoch 1736
#     computing connectivity for epoch 1737
#     computing connectivity for epoch 1738
#     computing connectivity for epoch 1739
#     computing connectivity for epoch 1740
#     computing connectivity for epoch 1741
#     computing connectivity for epoch 1742
#     computing connectivity for epoch 1743
#     computing connectivity for epoch 1744
#     computing connectivity for epoch 1745
#     computing connectivity for epoch 1746
#     computing connectivity for epoch 1747
#     computing connectivity for epoch 1748
#     computing connectivity for epoch 1749
#     computing connectivity for epoch 1750
#     computing connectivity for epoch 1751
#     computing connectivity for epoch 1752
#     computing connectivity for epoch 1753
#     computing connectivity for epoch 1754
#     computing connectivity for epoch 1755
#     computing connectivity for epoch 1756
#     computing connectivity for epoch 1757
#     computing connectivity for epoch 1758
#     computing connectivity for epoch 1759
#     computing connectivity for epoch 1760
#     computing connectivity for epoch 1761
#     computing connectivity for epoch 1762
#     computing connectivity for epoch 1763
#     computing connectivity for epoch 1764
#     computing connectivity for epoch 1765
#     computing connectivity for epoch 1766
#     computing connectivity for epoch 1767
#     computing connectivity for epoch 1768
#     computing connectivity for epoch 1769
#     computing connectivity for epoch 1770
#     computing connectivity for epoch 1771
#     computing connectivity for epoch 1772
#     computing connectivity for epoch 1773
#     computing connectivity for epoch 1774
#     computing connectivity for epoch 1775
#     computing connectivity for epoch 1776
#     computing connectivity for epoch 1777
#     computing connectivity for epoch 1778
#     computing connectivity for epoch 1779
#     computing connectivity for epoch 1780
#     computing connectivity for epoch 1781
#     computing connectivity for epoch 1782
#     computing connectivity for epoch 1783
#     computing connectivity for epoch 1784
#     computing connectivity for epoch 1785
#     computing connectivity for epoch 1786
#     computing connectivity for epoch 1787
#     computing connectivity for epoch 1788
#     computing connectivity for epoch 1789
#     computing connectivity for epoch 1790
#     computing connectivity for epoch 1791
#     computing connectivity for epoch 1792
#     computing connectivity for epoch 1793
#     computing connectivity for epoch 1794
#     computing connectivity for epoch 1795
#     computing connectivity for epoch 1796
#     computing connectivity for epoch 1797
#     computing connectivity for epoch 1798
#     computing connectivity for epoch 1799
#     computing connectivity for epoch 1800
#     computing connectivity for epoch 1801
#     computing connectivity for epoch 1802
#     computing connectivity for epoch 1803
#     computing connectivity for epoch 1804
#     computing connectivity for epoch 1805
#     computing connectivity for epoch 1806
#     computing connectivity for epoch 1807
#     computing connectivity for epoch 1808
#     computing connectivity for epoch 1809
#     computing connectivity for epoch 1810
#     computing connectivity for epoch 1811
#     computing connectivity for epoch 1812
#     computing connectivity for epoch 1813
#     computing connectivity for epoch 1814
#     computing connectivity for epoch 1815
#     computing connectivity for epoch 1816
#     computing connectivity for epoch 1817
#     computing connectivity for epoch 1818
#     computing connectivity for epoch 1819
#     computing connectivity for epoch 1820
#     computing connectivity for epoch 1821
#     computing connectivity for epoch 1822
#     computing connectivity for epoch 1823
#     computing connectivity for epoch 1824
#     computing connectivity for epoch 1825
#     computing connectivity for epoch 1826
#     computing connectivity for epoch 1827
#     computing connectivity for epoch 1828
#     computing connectivity for epoch 1829
#     computing connectivity for epoch 1830
#     computing connectivity for epoch 1831
#     computing connectivity for epoch 1832
#     computing connectivity for epoch 1833
#     computing connectivity for epoch 1834
#     computing connectivity for epoch 1835
#     computing connectivity for epoch 1836
#     computing connectivity for epoch 1837
#     computing connectivity for epoch 1838
#     computing connectivity for epoch 1839
#     computing connectivity for epoch 1840
#     computing connectivity for epoch 1841
#     computing connectivity for epoch 1842
#     computing connectivity for epoch 1843
#     computing connectivity for epoch 1844
#     computing connectivity for epoch 1845
#     computing connectivity for epoch 1846
#     computing connectivity for epoch 1847
#     computing connectivity for epoch 1848
#     computing connectivity for epoch 1849
#     computing connectivity for epoch 1850
#     computing connectivity for epoch 1851
#     computing connectivity for epoch 1852
#     computing connectivity for epoch 1853
#     computing connectivity for epoch 1854
#     computing connectivity for epoch 1855
#     computing connectivity for epoch 1856
#     computing connectivity for epoch 1857
#     computing connectivity for epoch 1858
#     computing connectivity for epoch 1859
#     computing connectivity for epoch 1860
#     computing connectivity for epoch 1861
#     computing connectivity for epoch 1862
#     computing connectivity for epoch 1863
#     computing connectivity for epoch 1864
#     computing connectivity for epoch 1865
#     computing connectivity for epoch 1866
#     computing connectivity for epoch 1867
#     computing connectivity for epoch 1868
#     computing connectivity for epoch 1869
#     computing connectivity for epoch 1870
#     computing connectivity for epoch 1871
#     computing connectivity for epoch 1872
#     computing connectivity for epoch 1873
#     computing connectivity for epoch 1874
#     computing connectivity for epoch 1875
#     computing connectivity for epoch 1876
#     computing connectivity for epoch 1877
#     computing connectivity for epoch 1878
#     computing connectivity for epoch 1879
#     computing connectivity for epoch 1880
#     computing connectivity for epoch 1881
#     computing connectivity for epoch 1882
#     computing connectivity for epoch 1883
#     computing connectivity for epoch 1884
#     computing connectivity for epoch 1885
#     computing connectivity for epoch 1886
#     computing connectivity for epoch 1887
#     computing connectivity for epoch 1888
#     computing connectivity for epoch 1889
#     computing connectivity for epoch 1890
#     computing connectivity for epoch 1891
#     computing connectivity for epoch 1892
#     computing connectivity for epoch 1893
#     computing connectivity for epoch 1894
#     computing connectivity for epoch 1895
#     computing connectivity for epoch 1896
#     computing connectivity for epoch 1897
#     computing connectivity for epoch 1898
#     computing connectivity for epoch 1899
#     computing connectivity for epoch 1900
#     computing connectivity for epoch 1901
#     computing connectivity for epoch 1902
#     computing connectivity for epoch 1903
#     computing connectivity for epoch 1904
#     computing connectivity for epoch 1905
#     computing connectivity for epoch 1906
#     computing connectivity for epoch 1907
#     computing connectivity for epoch 1908
#     computing connectivity for epoch 1909
#     computing connectivity for epoch 1910
#     computing connectivity for epoch 1911
#     computing connectivity for epoch 1912
#     computing connectivity for epoch 1913
#     computing connectivity for epoch 1914
#     computing connectivity for epoch 1915
#     computing connectivity for epoch 1916
#     computing connectivity for epoch 1917
#     computing connectivity for epoch 1918
#     computing connectivity for epoch 1919
#     computing connectivity for epoch 1920
#     computing connectivity for epoch 1921
#     computing connectivity for epoch 1922
# [Connectivity computation done]
# Frequencies in Hz over which coherence was averaged for 50 Hz:
# 49.96003197442046
# Frequencies in Hz over which coherence was averaged for 100 Hz:
# 99.9200639488409
# Frequencies in Hz over which coherence was averaged for 150 Hz:
# 149.88009592326136
# Frequencies in Hz over which coherence was averaged for 200 Hz:
# 199.8401278976818
# Frequencies in Hz over which coherence was averaged for 250 Hz:
# 249.80015987210226

# %%
# data = combined_epochs.get_data()
# freqs = np.array([50, 100, 150, 200, 250])
# foi = np.stack((freqs - 5, freqs + 5)).T
# # fmin = freq - 5
# # fmax = freqs + 5
# # foi = np.concatenate(fmin, fmax)
# foi
# coh = EpochSpectralConnectivity(
#     data, freqs, n_nodes = 310, indices = 'all',method = 'imcoh', mode='fourier')
# Out:
# array([[ 45,  55],
#        [ 95, 105],
#        [145, 155],
#        [195, 205],
#        [245, 255]])

# %%
# coh_df
# Out:
# array([[1.        , 0.03553919, 0.02375357, 0.01650441, 0.02783876,
#         0.02884122],
#        [1.        , 0.01756459, 0.00951065, 0.00633026, 0.01997641,
#         0.03273319],
#        [1.        , 0.03665346, 0.0345557 , 0.01859995, 0.0225321 ,
#         0.02535346],
#        [1.        , 0.0451385 , 0.02551724, 0.00623338, 0.03882852,
#         0.0268653 ],
#        [1.        , 0.01543893, 0.04209757, 0.03387247, 0.02253581,
#         0.00683295],
#        [1.        , 0.01974437, 0.00865967, 0.0217572 , 0.01489937,
#         0.03502125],
#        [1.        , 0.00477624, 0.006171  , 0.01789229, 0.03332508,
#         0.06969275],
#        [1.        , 0.00310636, 0.02242035, 0.02901781, 0.04138027,
#         0.03323897],
#        [1.        , 0.02747122, 0.04028795, 0.02742887, 0.02836565,
#         0.01463101],
#        [1.        , 0.01939304, 0.0252302 , 0.0211385 , 0.02685142,
#         0.07107452],
#        [1.        , 0.02859745, 0.03447119, 0.02963662, 0.02941357,
#         0.02297964],
#        [1.        , 0.01987881, 0.02933361, 0.0225366 , 0.06073463,
#         0.06944134],
#        [1.        , 0.02852567, 0.01792379, 0.02966675, 0.05261993,
#         0.10223265],
#        [1.        , 0.01690411, 0.03618631, 0.02143398, 0.04788554,
#         0.06378701],
#        [1.        , 0.04735591, 0.00858551, 0.02814018, 0.03191384,
#         0.02194833],
#        [1.        , 0.02779424, 0.0127707 , 0.02465404, 0.05579956,
#         0.05427035],
#        [1.        , 0.04375845, 0.01726223, 0.02857758, 0.03836001,
#         0.03518914],
#        [1.        , 0.0272215 , 0.01748158, 0.02750522, 0.02848963,
#         0.0411685 ],
#        [1.        , 0.03144412, 0.00649013, 0.01203129, 0.03375278,
#         0.08144765],
#        [1.        , 0.01874097, 0.0089475 , 0.01776572, 0.03254321,
#         0.03256908],
#        [1.        , 0.02649616, 0.02559119, 0.02235965, 0.02410431,
#         0.05825991],
#        [1.        , 0.02513494, 0.00661675, 0.00914272, 0.01769114,
#         0.04600938],
#        [1.        , 0.03116522, 0.00609943, 0.02070785, 0.02408727,
#         0.09170462],
#        [1.        , 0.01307405, 0.01490667, 0.0279793 , 0.01375513,
#         0.04120744],
#        [1.        , 0.02134958, 0.01203416, 0.00430172, 0.01325562,
#         0.03851707],
#        [1.        , 0.01355686, 0.01404192, 0.01105333, 0.01210165,
#         0.00355317],
#        [1.        , 0.01489977, 0.01988839, 0.01696153, 0.01600136,
#         0.01270943],
#        [1.        , 0.01535749, 0.02066648, 0.02226692, 0.01604612,
#         0.04505533],
#        [1.        , 0.02702978, 0.01312047, 0.0219486 , 0.00827242,
#         0.02495018],
#        [1.        , 0.01445716, 0.01769498, 0.0206242 , 0.01508201,
#         0.03733131],
#        [1.        , 0.24566569, 0.32544754, 0.40530563, 0.41463256,
#         0.42418152],
#        [1.        , 0.03370677, 0.01675396, 0.01056801, 0.02335001,
#         0.02716462],
#        [1.        , 0.05625862, 0.02994055, 0.00720932, 0.02199993,
#         0.01656643],
#        [1.        , 0.02648078, 0.01486997, 0.0096776 , 0.02163916,
#         0.0252701 ],
#        [1.        , 0.01721767, 0.01714445, 0.04191397, 0.01190849,
#         0.03675698],
#        [1.        , 0.03863085, 0.041149  , 0.0264407 , 0.04078362,
#         0.04402802],
#        [1.        , 0.01669825, 0.0097829 , 0.0296809 , 0.03875622,
#         0.04538471],
#        [1.        , 0.01518562, 0.01408451, 0.02041117, 0.04986609,
#         0.06509853],
#        [1.        , 0.02318723, 0.02763126, 0.02632443, 0.02606931,
#         0.04258216],
#        [1.        , 0.02378121, 0.03834022, 0.04214517, 0.03255168,
#         0.00702066],
#        [1.        , 0.010496  , 0.03174218, 0.02441562, 0.03925922,
#         0.04097847],
#        [1.        , 0.01467888, 0.02791046, 0.00819497, 0.05009767,
#         0.05612607],
#        [1.        , 0.0234183 , 0.03062468, 0.0217422 , 0.04180927,
#         0.04089352],
#        [1.        , 0.02115391, 0.02120734, 0.01352214, 0.04856569,
#         0.04905622],
#        [1.        , 0.01482451, 0.02571155, 0.02649027, 0.05090574,
#         0.04273075],
#        [1.        , 0.0400804 , 0.01414382, 0.03254768, 0.05015211,
#         0.0785089 ],
#        [1.        , 0.035843  , 0.01612031, 0.01615308, 0.04447309,
#         0.06082384],
#        [1.        , 0.02005923, 0.01071752, 0.01721035, 0.04279051,
#         0.02995615],
#        [1.        , 0.03492032, 0.00649746, 0.01898115, 0.02972279,
#         0.05444481],
#        [1.        , 0.03477001, 0.00731739, 0.03673593, 0.03218851,
#         0.08384912],
#        [1.        , 0.02432174, 0.01465503, 0.01724956, 0.03844085,
#         0.08798083],
#        [1.        , 0.02210774, 0.0058415 , 0.01931683, 0.01597738,
#         0.06815455],
#        [1.        , 0.01715616, 0.01891404, 0.01226168, 0.00983496,
#         0.01593883],
#        [1.        , 0.01928484, 0.02023241, 0.02709428, 0.01099706,
#         0.00728538],
#        [1.        , 0.01039218, 0.01276579, 0.02614368, 0.02523312,
#         0.08787048],
#        [1.        , 0.00921497, 0.0143997 , 0.02032582, 0.01385598,
#         0.02725556],
#        [1.        , 0.01764869, 0.02501077, 0.02841937, 0.01973535,
#         0.02806124],
#        [1.        , 0.02197253, 0.01459412, 0.01454451, 0.01183524,
#         0.01707203],
#        [1.        , 0.04642497, 0.01837348, 0.02572389, 0.01358082,
#         0.01256233],
#        [1.        , 0.03060453, 0.0231236 , 0.01625903, 0.01701116,
#         0.06319189],
#        [1.        , 0.01201193, 0.01700484, 0.01919416, 0.0149359 ,
#         0.09047182],
#        [1.        , 0.02194397, 0.02312347, 0.01088179, 0.03883944,
#         0.10101481]])

# %%
# spectral_connectivity_time(combined_epochs, indices = indices, sfreq = FS, foi = foi)
# Out:
# Adding metadata with 3 columns
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 spectral_connectivity_time(combined_epochs, indices = indices, sfreq = FS, foi = foi)
#
# File ~/.conda/envs/pitch-tracking/lib/python3.10/site-packages/mne_connectivity/spectral/time.py:199, in spectral_connectivity_time(data, names, method, indices, sfreq, foi, sm_times, sm_freqs, sm_kernel, mode, mt_bandwidth, freqs, n_cycles, decim, block_size, n_jobs, verbose)
#     196 else:
#     197     blocks = [np.arange(n_epochs)]
# --> 199 n_freqs = len(f_vec)
#     201 # compute coherence on blocks of trials
#     202 conn = np.zeros((n_epochs, n_pairs, n_freqs, len(times)))
#
# UnboundLocalError: local variable 'f_vec' referenced before assignment

# %%
# TRY SOME ANALYSES WITH THIS 

coh = spectral_connectivity_epochs(
    data, method='coh', mode='fourier', indices=indices,
    sfreq=FS, fmin=fmin, fmax=fmax, faverage=True, n_jobs=1)
freqs = coh.freqs

print('Frequencies in Hz over which coherence was averaged for 50 Hz: ')
print(freqs[0])
print('Frequencies in Hz over which coherence was averaged for 100 Hz: ')
print(freqs[1])
print('Frequencies in Hz over which coherence was averaged for 150 Hz: ')
print(freqs[2])
print('Frequencies in Hz over which coherence was averaged for 200 Hz: ')
print(freqs[3])
print('Frequencies in Hz over which coherence was averaged for 250 Hz: ')
print(freqs[4])

# %%
np.shape(coh) # n_chans * n_stim, n_freqs
# want it to be by n_trials also
print(np.shape(coh.get_data()))
coh.get_data()[120:125,:]
type(coh)
# COMPUTE COHERENCE SEPARATELY FOR EACH CONDITIONSNSN!!!

# TRY THE COH THAT ENDS IN TIME
# Out:
# (310, 5)
# mne_connectivity.base.SpectralConnectivity

# %%
# Create data frame (chan, stim_chan, coh_at_50hz, coh_at_100hz, coh_at_150, coh_at_200, coh_at_250)

# %%
epochs.events
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-34776b8512b9> in <module>()
# ----> 1 epochs.events
#
# NameError: name 'epochs' is not defined

# %%
mne.pick_types(combined_epochs.info, stim = True, eeg = True)

# %%
mne.pick_types(simulated_epochs.info, stim = True)
